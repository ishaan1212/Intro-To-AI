# %%
import random

def is_valid(board):
    n = len(board)
    for i in range(n):
        for j in range(i+1, n):
            if board[i] == board[j] or abs(board[i] - board[j]) == j - i:
                return False
    return True

def steepest_ascent_hill_climbing(n):
    success_count = 0
    total_steps_success = 0
    total_steps_failure = 0

    for _ in range(1000):
        # Create a more challenging starting configuration
        board = list(range(n))
        random.shuffle(board)
        steps = 0

        while True:
            current_attacks = sum([board.count(board[i]) - 1 for i in range(n)])

            if current_attacks == 0:
                success_count += 1
                total_steps_success += steps
                print(f"Successful run {success_count}: {board}")
                break

            best_board = list(board)
            best_attacks = current_attacks

            for i in range(n):
                for j in range(n):
                    board[i] = j
                    new_attacks = sum([board.count(board[k]) - 1 for k in range(n)])

                    if new_attacks < best_attacks:
                        best_board = list(board)
                        best_attacks = new_attacks

                    board[i] = best_board[i]

            if best_attacks >= current_attacks:
                total_steps_failure += steps
                print(f"Unsuccessful run {1000 - success_count}: {board}")
                break

            board = list(best_board)
            steps += 1

    return success_count, total_steps_success, total_steps_failure

if __name__ == "__main__":
    n = 8  # Change this to the desired number of queens
    success_count, total_steps_success, total_steps_failure = steepest_ascent_hill_climbing(n)
    print(f"Success rate: {success_count} out of 1000")

    if success_count > 0:
        avg_steps_success = total_steps_success / success_count
        print(f"Average steps when successful: {avg_steps_success}")
    else:
        print("No successful runs.")

    if success_count < 1000:
        avg_steps_failure = total_steps_failure / (1000 - success_count)
        print(f"Average steps when unsuccessful: {avg_steps_failure}")
    else:0
        print("No unsuccessful runs.")

    print(f"Succeeded {success_count} times out of 1000 runs.")
    print(f"Failed {1000 - success_count} times out of 1000 runs.")
# Out:
# Successful run 1: [7, 5, 4, 2, 6, 3, 0, 1]
# Successful run 2: [5, 3, 6, 7, 1, 0, 2, 4]
# Successful run 3: [5, 4, 3, 0, 6, 2, 1, 7]
# Successful run 4: [4, 5, 6, 3, 0, 2, 1, 7]
# Successful run 5: [7, 2, 5, 0, 6, 1, 4, 3]
# Successful run 6: [2, 1, 7, 0, 5, 4, 3, 6]
# Successful run 7: [7, 3, 6, 5, 2, 0, 1, 4]
# Successful run 8: [0, 6, 7, 2, 1, 5, 3, 4]
# Successful run 9: [4, 6, 0, 5, 1, 7, 2, 3]
# Successful run 10: [5, 0, 4, 7, 3, 1, 2, 6]
# Successful run 11: [2, 3, 0, 5, 4, 7, 6, 1]
# Successful run 12: [6, 7, 3, 5, 1, 2, 4, 0]
# Successful run 13: [1, 6, 3, 2, 4, 7, 5, 0]
# Successful run 14: [5, 0, 2, 1, 4, 6, 7, 3]
# Successful run 15: [0, 6, 4, 3, 5, 7, 2, 1]
# Successful run 16: [4, 3, 6, 0, 7, 1, 2, 5]
# Successful run 17: [6, 3, 0, 2, 5, 1, 4, 7]
# Successful run 18: [3, 1, 7, 4, 2, 6, 5, 0]
# Successful run 19: [3, 4, 2, 6, 7, 1, 0, 5]
# Successful run 20: [3, 4, 1, 6, 2, 0, 7, 5]
# Successful run 21: [1, 5, 4, 6, 2, 3, 7, 0]
# Successful run 22: [4, 1, 5, 6, 0, 3, 7, 2]
# Successful run 23: [6, 0, 5, 7, 2, 3, 4, 1]
# Successful run 24: [1, 3, 0, 2, 7, 4, 5, 6]
# Successful run 25: [7, 3, 5, 6, 4, 0, 1, 2]
# Successful run 26: [1, 4, 7, 6, 5, 2, 3, 0]
# Successful run 27: [4, 7, 2, 5, 0, 3, 1, 6]
# Successful run 28: [1, 0, 6, 3, 5, 4, 7, 2]
# Successful run 29: [2, 1, 3, 4, 0, 5, 7, 6]
# Successful run 30: [1, 2, 3, 5, 7, 4, 0, 6]
# Successful run 31: [2, 1, 3, 5, 6, 7, 4, 0]
# Successful run 32: [6, 1, 5, 0, 2, 4, 7, 3]
# Successful run 33: [7, 4, 3, 1, 5, 2, 6, 0]
# Successful run 34: [4, 5, 7, 0, 6, 3, 1, 2]
# Successful run 35: [7, 0, 6, 4, 1, 5, 3, 2]
# Successful run 36: [0, 3, 2, 4, 1, 7, 5, 6]
# Successful run 37: [6, 4, 2, 7, 0, 5, 1, 3]
# Successful run 38: [4, 0, 3, 6, 1, 5, 2, 7]
# Successful run 39: [6, 7, 5, 4, 0, 1, 2, 3]
# Successful run 40: [6, 5, 3, 2, 7, 1, 0, 4]
# Successful run 41: [5, 4, 1, 2, 6, 0, 7, 3]
# Successful run 42: [4, 2, 7, 1, 6, 5, 0, 3]
# Successful run 43: [0, 2, 6, 4, 1, 3, 5, 7]
# Successful run 44: [0, 4, 3, 1, 6, 2, 7, 5]
# Successful run 45: [4, 6, 5, 3, 7, 1, 0, 2]
# Successful run 46: [1, 0, 6, 3, 5, 4, 7, 2]
# Successful run 47: [3, 0, 2, 1, 7, 5, 6, 4]
# Successful run 48: [6, 0, 3, 7, 5, 1, 4, 2]
# Successful run 49: [7, 4, 1, 5, 2, 6, 3, 0]
# Successful run 50: [4, 7, 3, 1, 5, 6, 2, 0]
# Successful run 51: [5, 7, 1, 3, 0, 6, 4, 2]
# Successful run 52: [2, 4, 5, 0, 1, 3, 7, 6]
# Successful run 53: [0, 3, 5, 6, 4, 7, 2, 1]
# Successful run 54: [4, 0, 7, 3, 2, 5, 6, 1]
# Successful run 55: [5, 7, 2, 6, 1, 3, 0, 4]
# Successful run 56: [3, 2, 1, 4, 5, 6, 7, 0]
# Successful run 57: [6, 5, 3, 0, 7, 4, 1, 2]
# Successful run 58: [0, 4, 7, 3, 6, 1, 5, 2]
# Successful run 59: [3, 2, 6, 0, 5, 7, 1, 4]
# Successful run 60: [1, 6, 0, 7, 2, 5, 4, 3]
# Successful run 61: [7, 2, 0, 3, 6, 5, 1, 4]
# Successful run 62: [7, 5, 4, 0, 6, 1, 2, 3]
# Successful run 63: [6, 7, 3, 5, 1, 2, 0, 4]
# Successful run 64: [2, 1, 7, 3, 4, 0, 5, 6]
# Successful run 65: [3, 1, 7, 2, 4, 0, 6, 5]
# Successful run 66: [7, 3, 6, 5, 0, 2, 1, 4]
# Successful run 67: [4, 6, 1, 5, 0, 3, 2, 7]
# Successful run 68: [0, 6, 2, 3, 7, 4, 1, 5]
# Successful run 69: [5, 1, 6, 3, 4, 7, 2, 0]
# Successful run 70: [3, 2, 7, 6, 4, 1, 0, 5]
# Successful run 71: [7, 6, 0, 5, 3, 4, 2, 1]
# Successful run 72: [1, 3, 4, 2, 0, 6, 5, 7]
# Successful run 73: [6, 1, 2, 0, 5, 3, 4, 7]
# Successful run 74: [2, 7, 6, 5, 0, 3, 4, 1]
# Successful run 75: [1, 7, 3, 2, 4, 6, 0, 5]
# Successful run 76: [1, 3, 6, 5, 0, 4, 7, 2]
# Successful run 77: [5, 1, 6, 0, 2, 7, 4, 3]
# Successful run 78: [0, 4, 2, 6, 5, 7, 1, 3]
# Successful run 79: [2, 5, 6, 1, 0, 4, 7, 3]
# Successful run 80: [6, 0, 1, 4, 7, 2, 5, 3]
# Successful run 81: [2, 5, 3, 7, 6, 4, 0, 1]
# Successful run 82: [2, 6, 0, 7, 1, 5, 3, 4]
# Successful run 83: [6, 1, 5, 0, 7, 4, 2, 3]
# Successful run 84: [6, 4, 3, 5, 2, 7, 0, 1]
# Successful run 85: [4, 7, 2, 3, 1, 5, 0, 6]
# Successful run 86: [5, 3, 0, 7, 1, 2, 6, 4]
# Successful run 87: [1, 3, 7, 0, 2, 4, 6, 5]
# Successful run 88: [4, 0, 3, 1, 6, 2, 7, 5]
# Successful run 89: [5, 3, 7, 1, 6, 4, 2, 0]
# Successful run 90: [4, 7, 6, 0, 5, 1, 2, 3]
# Successful run 91: [5, 7, 2, 3, 0, 6, 4, 1]
# Successful run 92: [5, 1, 0, 7, 2, 4, 3, 6]
# Successful run 93: [4, 1, 2, 7, 5, 6, 0, 3]
# Successful run 94: [1, 4, 5, 6, 0, 3, 2, 7]
# Successful run 95: [3, 1, 0, 7, 2, 6, 4, 5]
# Successful run 96: [2, 6, 5, 7, 1, 3, 4, 0]
# Successful run 97: [2, 1, 5, 3, 6, 4, 0, 7]
# Successful run 98: [3, 4, 6, 1, 2, 5, 0, 7]
# Successful run 99: [6, 4, 2, 5, 1, 7, 3, 0]
# Successful run 100: [1, 4, 3, 7, 5, 2, 6, 0]
# Successful run 101: [2, 7, 5, 0, 3, 6, 1, 4]
# Successful run 102: [1, 4, 0, 7, 5, 3, 6, 2]
# Successful run 103: [0, 3, 4, 7, 1, 2, 6, 5]
# Successful run 104: [7, 4, 6, 3, 1, 0, 5, 2]
# Successful run 105: [1, 2, 0, 5, 6, 7, 3, 4]
# Successful run 106: [7, 1, 4, 0, 3, 5, 6, 2]
# Successful run 107: [2, 6, 1, 7, 4, 3, 0, 5]
# Successful run 108: [1, 7, 0, 6, 3, 5, 4, 2]
# Successful run 109: [4, 0, 3, 6, 2, 7, 5, 1]
# Successful run 110: [6, 2, 3, 4, 0, 1, 5, 7]
# Successful run 111: [2, 4, 1, 6, 3, 5, 0, 7]
# Successful run 112: [2, 3, 5, 1, 7, 6, 4, 0]
# Successful run 113: [7, 4, 3, 5, 1, 6, 0, 2]
# Successful run 114: [5, 2, 7, 6, 0, 1, 3, 4]
# Successful run 115: [7, 3, 4, 1, 6, 2, 5, 0]
# Successful run 116: [0, 3, 6, 4, 5, 1, 2, 7]
# Successful run 117: [5, 0, 1, 2, 4, 7, 6, 3]
# Successful run 118: [4, 6, 2, 3, 0, 7, 1, 5]
# Successful run 119: [5, 7, 4, 1, 2, 3, 6, 0]
# Successful run 120: [1, 5, 4, 3, 7, 2, 0, 6]
# Successful run 121: [3, 4, 2, 7, 0, 6, 1, 5]
# Successful run 122: [3, 4, 5, 2, 6, 1, 0, 7]
# Successful run 123: [6, 0, 7, 2, 4, 3, 5, 1]
# Successful run 124: [4, 2, 3, 6, 7, 5, 1, 0]
# Successful run 125: [1, 4, 5, 0, 3, 2, 7, 6]
# Successful run 126: [6, 4, 5, 2, 7, 3, 1, 0]
# Successful run 127: [0, 1, 4, 6, 7, 5, 2, 3]
# Successful run 128: [6, 7, 0, 3, 5, 2, 4, 1]
# Successful run 129: [1, 2, 7, 6, 3, 5, 4, 0]
# Successful run 130: [1, 4, 3, 2, 0, 6, 5, 7]
# Successful run 131: [5, 1, 4, 6, 7, 2, 3, 0]
# Successful run 132: [4, 3, 6, 2, 0, 7, 5, 1]
# Successful run 133: [1, 5, 7, 6, 0, 3, 2, 4]
# Successful run 134: [0, 1, 4, 6, 2, 3, 5, 7]
# Successful run 135: [6, 1, 3, 7, 5, 2, 4, 0]
# Successful run 136: [7, 5, 4, 0, 2, 1, 6, 3]
# Successful run 137: [4, 6, 1, 5, 3, 2, 7, 0]
# Successful run 138: [3, 1, 7, 2, 6, 0, 4, 5]
# Successful run 139: [6, 0, 3, 5, 7, 1, 4, 2]
# Successful run 140: [5, 0, 3, 1, 4, 2, 6, 7]
# Successful run 141: [1, 5, 7, 4, 0, 3, 2, 6]
# Successful run 142: [6, 5, 3, 7, 2, 1, 4, 0]
# Successful run 143: [3, 2, 5, 7, 6, 0, 4, 1]
# Successful run 144: [5, 6, 1, 4, 0, 7, 3, 2]
# Successful run 145: [0, 2, 4, 5, 7, 3, 6, 1]
# Successful run 146: [1, 3, 6, 7, 4, 5, 2, 0]
# Successful run 147: [6, 4, 7, 3, 1, 5, 2, 0]
# Successful run 148: [5, 1, 4, 3, 0, 2, 6, 7]
# Successful run 149: [5, 1, 7, 6, 2, 3, 4, 0]
# Successful run 150: [0, 1, 2, 4, 6, 3, 5, 7]
# Successful run 151: [6, 1, 5, 0, 4, 3, 7, 2]
# Successful run 152: [2, 0, 7, 3, 4, 5, 1, 6]
# Successful run 153: [0, 3, 4, 6, 1, 5, 2, 7]
# Successful run 154: [1, 7, 4, 0, 2, 5, 3, 6]
# Successful run 155: [7, 1, 2, 3, 4, 6, 5, 0]
# Successful run 156: [2, 6, 1, 3, 4, 0, 7, 5]
# Successful run 157: [3, 2, 6, 1, 5, 0, 7, 4]
# Successful run 158: [7, 5, 1, 0, 4, 3, 6, 2]
# Successful run 159: [4, 1, 2, 5, 6, 7, 3, 0]
# Successful run 160: [6, 4, 0, 5, 3, 7, 1, 2]
# Successful run 161: [4, 6, 1, 5, 2, 0, 7, 3]
# Successful run 162: [6, 3, 4, 7, 0, 1, 2, 5]
# Successful run 163: [2, 5, 4, 0, 6, 7, 1, 3]
# Successful run 164: [3, 5, 1, 7, 2, 6, 0, 4]
# Successful run 165: [2, 6, 3, 7, 0, 1, 5, 4]
# Successful run 166: [7, 4, 2, 5, 6, 0, 1, 3]
# Successful run 167: [0, 1, 6, 4, 3, 5, 2, 7]
# Successful run 168: [7, 4, 6, 2, 0, 3, 1, 5]
# Successful run 169: [3, 4, 1, 2, 7, 0, 6, 5]
# Successful run 170: [0, 6, 2, 3, 1, 7, 5, 4]
# Successful run 171: [0, 7, 3, 5, 4, 6, 1, 2]
# Successful run 172: [0, 2, 3, 1, 4, 5, 6, 7]
# Successful run 173: [2, 6, 1, 5, 4, 3, 0, 7]
# Successful run 174: [5, 6, 4, 7, 1, 0, 3, 2]
# Successful run 175: [4, 0, 2, 5, 1, 6, 3, 7]
# Successful run 176: [4, 7, 5, 0, 1, 2, 3, 6]
# Successful run 177: [1, 5, 7, 0, 4, 6, 2, 3]
# Successful run 178: [7, 2, 0, 3, 4, 5, 1, 6]
# Successful run 179: [7, 1, 6, 5, 3, 4, 2, 0]
# Successful run 180: [3, 4, 7, 2, 6, 0, 1, 5]
# Successful run 181: [7, 6, 0, 3, 1, 5, 2, 4]
# Successful run 182: [2, 0, 4, 5, 1, 3, 6, 7]
# Successful run 183: [1, 5, 7, 3, 2, 6, 0, 4]
# Successful run 184: [5, 6, 4, 3, 1, 2, 7, 0]
# Successful run 185: [2, 0, 7, 5, 1, 4, 3, 6]
# Successful run 186: [7, 1, 3, 4, 6, 0, 2, 5]
# Successful run 187: [6, 0, 4, 2, 1, 7, 3, 5]
# Successful run 188: [4, 6, 2, 7, 1, 0, 3, 5]
# Successful run 189: [7, 0, 1, 6, 4, 2, 3, 5]
# Successful run 190: [1, 6, 7, 3, 4, 0, 2, 5]
# Successful run 191: [1, 3, 4, 2, 7, 6, 5, 0]
# Successful run 192: [6, 1, 2, 4, 5, 3, 7, 0]
# Successful run 193: [7, 4, 3, 2, 1, 6, 5, 0]
# Successful run 194: [6, 0, 7, 2, 3, 1, 5, 4]
# Successful run 195: [7, 4, 6, 1, 2, 3, 0, 5]
# Successful run 196: [2, 5, 1, 3, 0, 7, 4, 6]
# Successful run 197: [2, 3, 4, 7, 1, 5, 6, 0]
# Successful run 198: [2, 6, 1, 7, 3, 4, 0, 5]
# Successful run 199: [1, 5, 0, 7, 3, 4, 6, 2]
# Successful run 200: [6, 4, 0, 5, 2, 7, 1, 3]
# Successful run 201: [0, 2, 3, 6, 1, 5, 7, 4]
# Successful run 202: [5, 7, 2, 0, 3, 6, 1, 4]
# Successful run 203: [4, 5, 3, 1, 0, 6, 2, 7]
# Successful run 204: [0, 6, 4, 1, 7, 2, 5, 3]
# Successful run 205: [5, 0, 3, 1, 4, 6, 7, 2]
# Successful run 206: [3, 2, 5, 4, 1, 6, 0, 7]
# Successful run 207: [1, 7, 3, 5, 0, 2, 6, 4]
# Successful run 208: [5, 6, 1, 3, 7, 4, 0, 2]
# Successful run 209: [6, 2, 5, 7, 0, 1, 3, 4]
# Successful run 210: [0, 1, 4, 7, 6, 3, 5, 2]
# Successful run 211: [0, 5, 4, 3, 1, 6, 2, 7]
# Successful run 212: [3, 2, 5, 6, 0, 7, 4, 1]
# Successful run 213: [2, 6, 1, 4, 3, 0, 7, 5]
# Successful run 214: [1, 7, 0, 6, 4, 3, 5, 2]
# Successful run 215: [5, 2, 4, 1, 6, 7, 0, 3]
# Successful run 216: [6, 1, 7, 0, 5, 2, 4, 3]
# Successful run 217: [5, 7, 3, 2, 1, 6, 4, 0]
# Successful run 218: [1, 5, 7, 0, 3, 2, 6, 4]
# Successful run 219: [3, 1, 0, 6, 4, 2, 5, 7]
# Successful run 220: [2, 1, 0, 5, 6, 3, 4, 7]
# Successful run 221: [6, 4, 2, 7, 5, 1, 3, 0]
# Successful run 222: [5, 1, 7, 3, 6, 4, 2, 0]
# Successful run 223: [7, 6, 3, 0, 2, 1, 4, 5]
# Successful run 224: [5, 7, 6, 0, 4, 3, 1, 2]
# Successful run 225: [4, 3, 1, 7, 2, 5, 6, 0]
# Successful run 226: [5, 3, 2, 6, 0, 7, 1, 4]
# Successful run 227: [2, 0, 1, 7, 6, 4, 3, 5]
# Successful run 228: [0, 4, 7, 3, 2, 6, 5, 1]
# Successful run 229: [5, 1, 6, 0, 7, 2, 3, 4]
# Successful run 230: [6, 5, 3, 1, 7, 0, 2, 4]
# Successful run 231: [7, 3, 2, 6, 4, 1, 5, 0]
# Successful run 232: [5, 0, 2, 3, 4, 6, 1, 7]
# Successful run 233: [4, 6, 3, 0, 2, 5, 7, 1]
# Successful run 234: [6, 7, 3, 0, 1, 2, 5, 4]
# Successful run 235: [4, 3, 7, 1, 2, 0, 6, 5]
# Successful run 236: [5, 7, 1, 4, 6, 3, 2, 0]
# Successful run 237: [2, 3, 7, 4, 6, 1, 0, 5]
# Successful run 238: [7, 2, 1, 0, 5, 4, 6, 3]
# Successful run 239: [6, 1, 0, 4, 3, 5, 7, 2]
# Successful run 240: [1, 4, 2, 5, 0, 6, 7, 3]
# Successful run 241: [6, 4, 1, 0, 3, 7, 5, 2]
# Successful run 242: [3, 2, 7, 1, 6, 4, 5, 0]
# Successful run 243: [3, 1, 5, 2, 6, 7, 4, 0]
# Successful run 244: [3, 2, 1, 5, 6, 0, 4, 7]
# Successful run 245: [7, 5, 3, 6, 0, 2, 1, 4]
# Successful run 246: [2, 1, 3, 6, 7, 0, 4, 5]
# Successful run 247: [7, 4, 3, 6, 0, 2, 1, 5]
# Successful run 248: [6, 0, 3, 4, 7, 5, 1, 2]
# Successful run 249: [0, 1, 4, 6, 3, 5, 7, 2]
# Successful run 250: [0, 1, 2, 6, 3, 4, 7, 5]
# Successful run 251: [3, 4, 5, 2, 0, 6, 1, 7]
# Successful run 252: [0, 6, 4, 1, 2, 7, 5, 3]
# Successful run 253: [3, 5, 6, 0, 7, 1, 2, 4]
# Successful run 254: [6, 4, 3, 7, 0, 2, 5, 1]
# Successful run 255: [6, 2, 7, 3, 1, 4, 5, 0]
# Successful run 256: [5, 6, 0, 3, 4, 2, 7, 1]
# Successful run 257: [4, 2, 5, 7, 6, 0, 1, 3]
# Successful run 258: [6, 1, 4, 7, 5, 3, 0, 2]
# Successful run 259: [6, 3, 2, 4, 0, 7, 5, 1]
# Successful run 260: [0, 2, 6, 3, 7, 1, 4, 5]
# Successful run 261: [3, 1, 6, 0, 4, 2, 7, 5]
# Successful run 262: [2, 6, 4, 7, 5, 3, 1, 0]
# Successful run 263: [7, 5, 4, 6, 2, 3, 1, 0]
# Successful run 264: [4, 5, 3, 1, 0, 7, 2, 6]
# Successful run 265: [1, 5, 2, 0, 3, 7, 6, 4]
# Successful run 266: [7, 5, 2, 6, 0, 3, 4, 1]
# Successful run 267: [1, 0, 6, 4, 7, 3, 2, 5]
# Successful run 268: [4, 7, 3, 5, 0, 1, 6, 2]
# Successful run 269: [3, 7, 2, 4, 6, 1, 5, 0]
# Successful run 270: [6, 7, 0, 3, 4, 2, 5, 1]
# Successful run 271: [2, 6, 0, 1, 4, 7, 3, 5]
# Successful run 272: [7, 3, 2, 1, 0, 4, 5, 6]
# Successful run 273: [5, 3, 1, 2, 6, 4, 0, 7]
# Successful run 274: [3, 7, 2, 5, 1, 4, 6, 0]
# Successful run 275: [6, 0, 7, 4, 1, 5, 3, 2]
# Successful run 276: [3, 5, 6, 7, 1, 0, 2, 4]
# Successful run 277: [7, 6, 3, 4, 1, 5, 2, 0]
# Successful run 278: [5, 2, 0, 7, 1, 4, 3, 6]
# Successful run 279: [7, 6, 2, 1, 4, 3, 5, 0]
# Successful run 280: [1, 6, 5, 2, 0, 7, 3, 4]
# Successful run 281: [3, 5, 4, 0, 1, 6, 7, 2]
# Successful run 282: [3, 2, 0, 4, 6, 5, 7, 1]
# Successful run 283: [6, 2, 7, 4, 1, 3, 5, 0]
# Successful run 284: [2, 4, 5, 7, 6, 3, 1, 0]
# Successful run 285: [2, 7, 5, 6, 4, 0, 1, 3]
# Successful run 286: [0, 6, 2, 1, 3, 4, 7, 5]
# Successful run 287: [6, 5, 0, 2, 1, 7, 4, 3]
# Successful run 288: [1, 2, 3, 0, 4, 7, 6, 5]
# Successful run 289: [6, 2, 3, 1, 0, 7, 5, 4]
# Successful run 290: [6, 2, 3, 7, 4, 0, 5, 1]
# Successful run 291: [5, 1, 2, 6, 4, 7, 3, 0]
# Successful run 292: [0, 7, 5, 1, 3, 4, 6, 2]
# Successful run 293: [6, 0, 5, 4, 7, 3, 1, 2]
# Successful run 294: [0, 2, 4, 3, 1, 7, 6, 5]
# Successful run 295: [2, 4, 5, 0, 6, 7, 1, 3]
# Successful run 296: [3, 7, 2, 6, 4, 1, 5, 0]
# Successful run 297: [4, 3, 1, 6, 2, 0, 7, 5]
# Successful run 298: [3, 4, 5, 1, 7, 2, 0, 6]
# Successful run 299: [1, 6, 7, 5, 2, 0, 4, 3]
# Successful run 300: [7, 0, 1, 2, 3, 4, 5, 6]
# Successful run 301: [0, 1, 6, 3, 4, 7, 5, 2]
# Successful run 302: [6, 7, 2, 1, 5, 0, 4, 3]
# Successful run 303: [2, 7, 4, 5, 1, 0, 3, 6]
# Successful run 304: [5, 7, 4, 3, 6, 2, 0, 1]
# Successful run 305: [4, 5, 2, 7, 6, 1, 0, 3]
# Successful run 306: [3, 4, 5, 7, 6, 2, 0, 1]
# Successful run 307: [6, 5, 4, 0, 7, 1, 3, 2]
# Successful run 308: [6, 0, 3, 5, 4, 7, 2, 1]
# Successful run 309: [2, 3, 4, 0, 1, 5, 6, 7]
# Successful run 310: [4, 0, 5, 3, 6, 2, 7, 1]
# Successful run 311: [0, 3, 1, 7, 4, 5, 2, 6]
# Successful run 312: [2, 7, 0, 3, 1, 6, 4, 5]
# Successful run 313: [7, 5, 4, 2, 3, 6, 1, 0]
# Successful run 314: [4, 2, 6, 5, 3, 7, 1, 0]
# Successful run 315: [2, 6, 5, 3, 7, 1, 4, 0]
# Successful run 316: [0, 4, 1, 3, 2, 6, 7, 5]
# Successful run 317: [6, 0, 1, 7, 2, 4, 3, 5]
# Successful run 318: [1, 5, 3, 6, 7, 0, 2, 4]
# Successful run 319: [2, 1, 4, 5, 3, 6, 0, 7]
# Successful run 320: [0, 1, 6, 5, 4, 2, 3, 7]
# Successful run 321: [4, 7, 6, 2, 3, 1, 0, 5]
# Successful run 322: [2, 1, 6, 3, 4, 5, 0, 7]
# Successful run 323: [6, 7, 1, 5, 4, 3, 2, 0]
# Successful run 324: [6, 2, 1, 5, 3, 0, 7, 4]
# Successful run 325: [7, 1, 5, 2, 0, 6, 4, 3]
# Successful run 326: [5, 4, 2, 1, 7, 0, 3, 6]
# Successful run 327: [2, 1, 7, 5, 3, 4, 6, 0]
# Successful run 328: [5, 7, 1, 3, 4, 2, 0, 6]
# Successful run 329: [4, 7, 1, 2, 0, 6, 3, 5]
# Successful run 330: [3, 0, 4, 5, 2, 7, 6, 1]
# Successful run 331: [0, 2, 5, 4, 1, 7, 3, 6]
# Successful run 332: [3, 4, 6, 0, 1, 5, 2, 7]
# Successful run 333: [0, 1, 6, 4, 2, 7, 5, 3]
# Successful run 334: [3, 4, 2, 0, 7, 1, 5, 6]
# Successful run 335: [7, 3, 0, 4, 2, 5, 6, 1]
# Successful run 336: [6, 0, 3, 7, 4, 2, 5, 1]
# Successful run 337: [0, 4, 7, 2, 5, 1, 6, 3]
# Successful run 338: [4, 2, 5, 0, 3, 6, 1, 7]
# Successful run 339: [7, 5, 0, 6, 3, 4, 1, 2]
# Successful run 340: [0, 3, 7, 1, 6, 2, 5, 4]
# Successful run 341: [6, 1, 4, 3, 0, 7, 2, 5]
# Successful run 342: [1, 0, 5, 3, 7, 2, 6, 4]
# Successful run 343: [2, 6, 7, 4, 0, 3, 5, 1]
# Successful run 344: [2, 3, 0, 1, 5, 7, 4, 6]
# Successful run 345: [3, 6, 5, 1, 0, 4, 2, 7]
# Successful run 346: [1, 6, 5, 7, 3, 0, 4, 2]
# Successful run 347: [3, 5, 2, 1, 6, 4, 0, 7]
# Successful run 348: [1, 2, 0, 3, 5, 6, 7, 4]
# Successful run 349: [7, 1, 3, 2, 0, 5, 4, 6]
# Successful run 350: [2, 4, 5, 0, 6, 7, 3, 1]
# Successful run 351: [2, 3, 7, 1, 4, 5, 6, 0]
# Successful run 352: [5, 2, 6, 4, 1, 0, 7, 3]
# Successful run 353: [4, 3, 1, 6, 0, 5, 2, 7]
# Successful run 354: [1, 4, 5, 2, 6, 0, 7, 3]
# Successful run 355: [7, 3, 4, 2, 1, 5, 0, 6]
# Successful run 356: [5, 6, 4, 1, 7, 0, 2, 3]
# Successful run 357: [0, 7, 3, 1, 6, 2, 5, 4]
# Successful run 358: [6, 0, 5, 1, 2, 7, 3, 4]
# Successful run 359: [4, 3, 7, 6, 5, 0, 2, 1]
# Successful run 360: [3, 7, 0, 1, 4, 6, 2, 5]
# Successful run 361: [4, 0, 3, 1, 5, 7, 2, 6]
# Successful run 362: [1, 6, 5, 3, 4, 7, 2, 0]
# Successful run 363: [0, 6, 2, 4, 1, 5, 3, 7]
# Successful run 364: [7, 3, 2, 4, 0, 5, 1, 6]
# Successful run 365: [4, 3, 7, 6, 1, 5, 0, 2]
# Successful run 366: [2, 5, 7, 0, 4, 1, 6, 3]
# Successful run 367: [4, 7, 0, 5, 6, 2, 1, 3]
# Successful run 368: [5, 4, 0, 6, 2, 7, 1, 3]
# Successful run 369: [7, 0, 4, 5, 2, 1, 3, 6]
# Successful run 370: [1, 6, 5, 7, 4, 2, 0, 3]
# Successful run 371: [4, 3, 0, 2, 5, 1, 6, 7]
# Successful run 372: [7, 2, 4, 1, 3, 6, 0, 5]
# Successful run 373: [2, 4, 5, 7, 3, 1, 0, 6]
# Successful run 374: [6, 2, 4, 3, 5, 0, 7, 1]
# Successful run 375: [6, 4, 7, 0, 5, 3, 1, 2]
# Successful run 376: [5, 6, 4, 0, 2, 1, 7, 3]
# Successful run 377: [0, 1, 2, 7, 5, 3, 6, 4]
# Successful run 378: [1, 6, 4, 2, 0, 5, 7, 3]
# Successful run 379: [7, 5, 3, 0, 2, 4, 6, 1]
# Successful run 380: [1, 6, 5, 2, 3, 7, 0, 4]
# Successful run 381: [6, 4, 2, 5, 3, 0, 7, 1]
# Successful run 382: [0, 6, 1, 4, 3, 5, 2, 7]
# Successful run 383: [0, 7, 4, 3, 5, 1, 6, 2]
# Successful run 384: [5, 0, 2, 4, 7, 1, 6, 3]
# Successful run 385: [2, 4, 6, 3, 7, 5, 0, 1]
# Successful run 386: [4, 5, 0, 7, 2, 1, 3, 6]
# Successful run 387: [2, 7, 0, 1, 4, 6, 3, 5]
# Successful run 388: [0, 7, 4, 6, 2, 3, 1, 5]
# Successful run 389: [0, 1, 6, 4, 3, 7, 5, 2]
# Successful run 390: [3, 4, 1, 7, 6, 2, 5, 0]
# Successful run 391: [1, 6, 5, 0, 7, 4, 3, 2]
# Successful run 392: [7, 2, 6, 3, 4, 0, 1, 5]
# Successful run 393: [0, 3, 2, 6, 4, 5, 7, 1]
# Successful run 394: [4, 6, 3, 7, 5, 0, 1, 2]
# Successful run 395: [1, 5, 0, 6, 3, 4, 2, 7]
# Successful run 396: [1, 7, 0, 2, 4, 5, 6, 3]
# Successful run 397: [6, 1, 0, 2, 5, 7, 4, 3]
# Successful run 398: [1, 2, 6, 7, 5, 0, 3, 4]
# Successful run 399: [7, 3, 6, 2, 1, 4, 0, 5]
# Successful run 400: [3, 2, 0, 1, 5, 7, 4, 6]
# Successful run 401: [5, 6, 7, 0, 4, 2, 1, 3]
# Successful run 402: [2, 1, 6, 0, 3, 5, 7, 4]
# Successful run 403: [1, 0, 6, 7, 3, 2, 4, 5]
# Successful run 404: [0, 1, 3, 7, 4, 2, 6, 5]
# Successful run 405: [0, 3, 1, 5, 6, 2, 4, 7]
# Successful run 406: [4, 5, 0, 2, 7, 3, 1, 6]
# Successful run 407: [4, 7, 0, 3, 1, 6, 5, 2]
# Successful run 408: [1, 6, 0, 4, 5, 7, 2, 3]
# Successful run 409: [0, 5, 3, 2, 6, 1, 7, 4]
# Successful run 410: [7, 2, 1, 4, 5, 0, 6, 3]
# Successful run 411: [5, 3, 2, 7, 6, 4, 1, 0]
# Successful run 412: [7, 6, 3, 0, 1, 5, 2, 4]
# Successful run 413: [7, 6, 2, 3, 1, 5, 4, 0]
# Successful run 414: [7, 5, 1, 3, 2, 6, 0, 4]
# Successful run 415: [4, 6, 7, 2, 5, 0, 1, 3]
# Successful run 416: [0, 5, 7, 2, 3, 4, 6, 1]
# Successful run 417: [6, 0, 4, 2, 3, 5, 1, 7]
# Successful run 418: [4, 5, 2, 6, 1, 0, 7, 3]
# Successful run 419: [7, 2, 1, 6, 5, 3, 0, 4]
# Successful run 420: [1, 0, 6, 5, 2, 7, 3, 4]
# Successful run 421: [2, 5, 3, 1, 6, 0, 4, 7]
# Successful run 422: [7, 2, 1, 3, 6, 5, 0, 4]
# Successful run 423: [3, 7, 0, 6, 1, 4, 2, 5]
# Successful run 424: [6, 4, 2, 1, 3, 0, 5, 7]
# Successful run 425: [2, 6, 4, 3, 0, 5, 1, 7]
# Successful run 426: [3, 0, 5, 1, 4, 6, 7, 2]
# Successful run 427: [4, 2, 3, 7, 1, 0, 5, 6]
# Successful run 428: [2, 7, 1, 0, 5, 3, 6, 4]
# Successful run 429: [7, 4, 0, 5, 2, 1, 3, 6]
# Successful run 430: [1, 2, 7, 6, 5, 4, 0, 3]
# Successful run 431: [4, 0, 7, 2, 5, 1, 6, 3]
# Successful run 432: [1, 7, 6, 2, 5, 4, 3, 0]
# Successful run 433: [7, 2, 6, 5, 1, 3, 4, 0]
# Successful run 434: [5, 3, 2, 7, 1, 6, 4, 0]
# Successful run 435: [1, 7, 5, 0, 3, 6, 2, 4]
# Successful run 436: [3, 0, 1, 7, 5, 6, 4, 2]
# Successful run 437: [5, 2, 4, 7, 6, 0, 1, 3]
# Successful run 438: [7, 4, 5, 2, 0, 6, 3, 1]
# Successful run 439: [4, 7, 6, 3, 1, 5, 0, 2]
# Successful run 440: [7, 1, 4, 2, 3, 0, 6, 5]
# Successful run 441: [2, 0, 7, 6, 5, 3, 1, 4]
# Successful run 442: [5, 3, 4, 0, 2, 6, 7, 1]
# Successful run 443: [4, 7, 2, 0, 6, 1, 5, 3]
# Successful run 444: [2, 5, 6, 3, 7, 4, 1, 0]
# Successful run 445: [0, 6, 7, 3, 2, 4, 5, 1]
# Successful run 446: [2, 3, 5, 6, 0, 4, 7, 1]
# Successful run 447: [6, 1, 7, 0, 2, 3, 5, 4]
# Successful run 448: [0, 6, 7, 2, 1, 3, 4, 5]
# Successful run 449: [4, 6, 2, 0, 1, 5, 3, 7]
# Successful run 450: [7, 5, 6, 0, 3, 4, 2, 1]
# Successful run 451: [7, 1, 6, 4, 3, 0, 2, 5]
# Successful run 452: [0, 2, 7, 4, 5, 6, 3, 1]
# Successful run 453: [7, 4, 3, 0, 5, 2, 6, 1]
# Successful run 454: [4, 7, 3, 2, 1, 0, 5, 6]
# Successful run 455: [3, 5, 6, 2, 0, 7, 4, 1]
# Successful run 456: [3, 5, 0, 7, 4, 1, 6, 2]
# Successful run 457: [4, 0, 5, 6, 2, 3, 7, 1]
# Successful run 458: [6, 3, 7, 0, 2, 5, 4, 1]
# Successful run 459: [7, 6, 4, 2, 0, 1, 3, 5]
# Successful run 460: [1, 6, 7, 4, 3, 5, 2, 0]
# Successful run 461: [3, 7, 1, 6, 2, 5, 0, 4]
# Successful run 462: [2, 1, 5, 7, 0, 3, 4, 6]
# Successful run 463: [5, 2, 4, 6, 0, 3, 7, 1]
# Successful run 464: [2, 6, 4, 5, 7, 3, 0, 1]
# Successful run 465: [2, 1, 3, 4, 5, 6, 0, 7]
# Successful run 466: [4, 5, 3, 6, 2, 1, 7, 0]
# Successful run 467: [4, 7, 5, 3, 6, 1, 2, 0]
# Successful run 468: [7, 5, 2, 4, 0, 1, 3, 6]
# Successful run 469: [5, 7, 6, 0, 4, 3, 1, 2]
# Successful run 470: [5, 2, 1, 6, 4, 3, 7, 0]
# Successful run 471: [7, 4, 1, 2, 0, 6, 5, 3]
# Successful run 472: [6, 1, 5, 4, 0, 7, 2, 3]
# Successful run 473: [7, 2, 3, 6, 1, 4, 0, 5]
# Successful run 474: [5, 1, 7, 4, 3, 2, 0, 6]
# Successful run 475: [0, 3, 4, 1, 5, 7, 2, 6]
# Successful run 476: [7, 2, 5, 6, 0, 1, 4, 3]
# Successful run 477: [0, 1, 4, 3, 7, 2, 6, 5]
# Successful run 478: [4, 0, 5, 6, 7, 1, 2, 3]
# Successful run 479: [0, 4, 5, 6, 7, 2, 1, 3]
# Successful run 480: [3, 5, 2, 7, 4, 1, 6, 0]
# Successful run 481: [0, 4, 2, 3, 7, 1, 5, 6]
# Successful run 482: [1, 6, 4, 0, 7, 3, 2, 5]
# Successful run 483: [2, 4, 1, 5, 3, 6, 0, 7]
# Successful run 484: [5, 1, 6, 2, 4, 7, 0, 3]
# Successful run 485: [4, 1, 0, 7, 6, 3, 5, 2]
# Successful run 486: [6, 4, 0, 2, 1, 3, 7, 5]
# Successful run 487: [0, 3, 6, 7, 4, 2, 1, 5]
# Successful run 488: [0, 2, 1, 7, 6, 5, 3, 4]
# Successful run 489: [3, 0, 4, 5, 1, 7, 6, 2]
# Successful run 490: [1, 0, 4, 2, 3, 6, 5, 7]
# Successful run 491: [3, 0, 2, 1, 6, 7, 5, 4]
# Successful run 492: [2, 3, 0, 6, 5, 4, 1, 7]
# Successful run 493: [4, 2, 3, 7, 1, 5, 0, 6]
# Successful run 494: [1, 0, 5, 7, 6, 2, 3, 4]
# Successful run 495: [5, 6, 4, 1, 2, 7, 3, 0]
# Successful run 496: [7, 3, 6, 1, 4, 0, 2, 5]
# Successful run 497: [0, 5, 7, 4, 6, 1, 2, 3]
# Successful run 498: [5, 1, 6, 0, 7, 4, 3, 2]
# Successful run 499: [7, 1, 6, 5, 3, 0, 2, 4]
# Successful run 500: [1, 6, 2, 5, 4, 7, 0, 3]
# Successful run 501: [3, 4, 7, 2, 6, 1, 5, 0]
# Successful run 502: [1, 4, 2, 7, 5, 6, 3, 0]
# Successful run 503: [0, 1, 7, 2, 4, 5, 3, 6]
# Successful run 504: [6, 7, 3, 2, 0, 4, 1, 5]
# Successful run 505: [1, 5, 3, 0, 2, 6, 7, 4]
# Successful run 506: [0, 4, 6, 7, 2, 1, 3, 5]
# Successful run 507: [0, 2, 4, 1, 6, 7, 5, 3]
# Successful run 508: [2, 1, 6, 0, 3, 5, 7, 4]
# Successful run 509: [1, 4, 0, 7, 6, 3, 5, 2]
# Successful run 510: [4, 7, 3, 0, 1, 2, 6, 5]
# Successful run 511: [4, 7, 5, 6, 1, 0, 3, 2]
# Successful run 512: [7, 2, 4, 5, 3, 1, 6, 0]
# Successful run 513: [3, 1, 5, 2, 6, 4, 7, 0]
# Successful run 514: [5, 2, 6, 3, 4, 0, 7, 1]
# Successful run 515: [7, 1, 0, 5, 3, 2, 6, 4]
# Successful run 516: [7, 2, 6, 1, 3, 4, 0, 5]
# Successful run 517: [3, 7, 6, 2, 0, 4, 1, 5]
# Successful run 518: [4, 5, 7, 2, 3, 6, 0, 1]
# Successful run 519: [4, 7, 1, 0, 5, 6, 3, 2]
# Successful run 520: [0, 5, 4, 3, 1, 2, 6, 7]
# Successful run 521: [2, 0, 3, 1, 7, 5, 4, 6]
# Successful run 522: [5, 3, 1, 2, 6, 0, 7, 4]
# Successful run 523: [5, 3, 0, 6, 4, 2, 7, 1]
# Successful run 524: [7, 2, 3, 4, 1, 0, 5, 6]
# Successful run 525: [4, 2, 0, 3, 1, 5, 6, 7]
# Successful run 526: [6, 2, 4, 0, 7, 5, 1, 3]
# Successful run 527: [6, 5, 2, 7, 3, 0, 4, 1]
# Successful run 528: [2, 6, 7, 5, 4, 0, 1, 3]
# Successful run 529: [1, 5, 4, 0, 2, 3, 7, 6]
# Successful run 530: [7, 2, 1, 3, 5, 6, 0, 4]
# Successful run 531: [3, 0, 6, 5, 1, 7, 2, 4]
# Successful run 532: [1, 7, 4, 2, 6, 5, 0, 3]
# Successful run 533: [7, 3, 0, 4, 5, 6, 2, 1]
# Successful run 534: [2, 4, 6, 5, 0, 7, 1, 3]
# Successful run 535: [2, 5, 0, 1, 6, 7, 4, 3]
# Successful run 536: [3, 6, 0, 2, 1, 4, 7, 5]
# Successful run 537: [0, 5, 6, 1, 3, 2, 7, 4]
# Successful run 538: [7, 2, 0, 6, 5, 3, 1, 4]
# Successful run 539: [1, 7, 0, 3, 6, 5, 2, 4]
# Successful run 540: [4, 7, 1, 0, 2, 3, 5, 6]
# Successful run 541: [5, 2, 4, 3, 0, 1, 6, 7]
# Successful run 542: [3, 7, 6, 1, 4, 2, 5, 0]
# Successful run 543: [6, 1, 0, 7, 4, 5, 2, 3]
# Successful run 544: [3, 2, 1, 7, 6, 0, 5, 4]
# Successful run 545: [2, 6, 7, 3, 1, 0, 4, 5]
# Successful run 546: [3, 0, 1, 7, 5, 2, 4, 6]
# Successful run 547: [0, 6, 4, 5, 1, 2, 7, 3]
# Successful run 548: [6, 1, 3, 4, 0, 7, 2, 5]
# Successful run 549: [6, 5, 4, 0, 1, 7, 2, 3]
# Successful run 550: [7, 1, 2, 6, 0, 4, 5, 3]
# Successful run 551: [4, 3, 7, 5, 6, 2, 1, 0]
# Successful run 552: [4, 7, 0, 1, 3, 5, 2, 6]
# Successful run 553: [6, 4, 2, 0, 7, 1, 3, 5]
# Successful run 554: [2, 3, 1, 0, 6, 7, 5, 4]
# Successful run 555: [4, 6, 5, 2, 7, 1, 3, 0]
# Successful run 556: [6, 3, 5, 7, 2, 0, 4, 1]
# Successful run 557: [1, 4, 7, 5, 0, 3, 2, 6]
# Successful run 558: [2, 4, 0, 3, 7, 1, 6, 5]
# Successful run 559: [7, 2, 5, 3, 0, 4, 6, 1]
# Successful run 560: [3, 4, 7, 6, 5, 1, 0, 2]
# Successful run 561: [1, 7, 4, 6, 3, 2, 5, 0]
# Successful run 562: [3, 2, 4, 0, 1, 6, 5, 7]
# Successful run 563: [6, 5, 0, 2, 7, 3, 4, 1]
# Successful run 564: [4, 0, 7, 1, 2, 6, 3, 5]
# Successful run 565: [0, 3, 5, 6, 2, 7, 4, 1]
# Successful run 566: [0, 1, 6, 7, 5, 3, 2, 4]
# Successful run 567: [7, 0, 1, 2, 6, 3, 4, 5]
# Successful run 568: [7, 0, 1, 5, 3, 4, 2, 6]
# Successful run 569: [0, 5, 6, 2, 3, 1, 7, 4]
# Successful run 570: [4, 1, 2, 0, 7, 3, 5, 6]
# Successful run 571: [1, 2, 4, 3, 7, 6, 0, 5]
# Successful run 572: [3, 2, 4, 0, 1, 6, 7, 5]
# Successful run 573: [3, 6, 7, 4, 1, 0, 2, 5]
# Successful run 574: [0, 1, 7, 6, 3, 5, 4, 2]
# Successful run 575: [3, 6, 5, 0, 4, 1, 2, 7]
# Successful run 576: [1, 4, 2, 7, 3, 0, 5, 6]
# Successful run 577: [3, 4, 5, 0, 1, 2, 6, 7]
# Successful run 578: [4, 0, 5, 1, 2, 7, 3, 6]
# Successful run 579: [6, 5, 1, 7, 0, 4, 3, 2]
# Successful run 580: [7, 1, 4, 6, 2, 5, 0, 3]
# Successful run 581: [2, 4, 7, 6, 3, 1, 5, 0]
# Successful run 582: [7, 4, 3, 0, 1, 6, 2, 5]
# Successful run 583: [3, 7, 1, 4, 0, 6, 2, 5]
# Successful run 584: [4, 6, 5, 1, 7, 3, 0, 2]
# Successful run 585: [1, 4, 6, 7, 3, 2, 0, 5]
# Successful run 586: [2, 6, 7, 5, 4, 0, 1, 3]
# Successful run 587: [2, 3, 0, 5, 1, 4, 6, 7]
# Successful run 588: [5, 4, 6, 3, 0, 1, 7, 2]
# Successful run 589: [3, 6, 5, 7, 4, 0, 2, 1]
# Successful run 590: [1, 6, 4, 3, 5, 2, 0, 7]
# Successful run 591: [4, 0, 6, 7, 2, 3, 5, 1]
# Successful run 592: [3, 5, 7, 4, 1, 6, 0, 2]
# Successful run 593: [4, 7, 1, 2, 3, 0, 5, 6]
# Successful run 594: [7, 3, 2, 1, 6, 0, 5, 4]
# Successful run 595: [2, 4, 0, 7, 5, 6, 3, 1]
# Successful run 596: [0, 6, 3, 4, 1, 7, 5, 2]
# Successful run 597: [7, 0, 6, 5, 3, 2, 1, 4]
# Successful run 598: [5, 0, 7, 4, 1, 6, 3, 2]
# Successful run 599: [5, 6, 0, 3, 1, 2, 7, 4]
# Successful run 600: [7, 3, 6, 0, 2, 4, 5, 1]
# Successful run 601: [3, 6, 2, 4, 7, 5, 1, 0]
# Successful run 602: [0, 6, 3, 1, 7, 5, 4, 2]
# Successful run 603: [4, 6, 2, 3, 7, 5, 1, 0]
# Successful run 604: [5, 4, 2, 7, 1, 6, 0, 3]
# Successful run 605: [4, 5, 6, 2, 0, 1, 3, 7]
# Successful run 606: [2, 3, 5, 4, 6, 7, 0, 1]
# Successful run 607: [6, 3, 5, 0, 2, 1, 7, 4]
# Successful run 608: [3, 5, 2, 1, 6, 4, 0, 7]
# Successful run 609: [1, 3, 6, 2, 5, 0, 4, 7]
# Successful run 610: [4, 6, 5, 7, 1, 3, 2, 0]
# Successful run 611: [0, 1, 4, 7, 2, 6, 5, 3]
# Successful run 612: [0, 5, 2, 4, 6, 1, 3, 7]
# Successful run 613: [0, 2, 3, 6, 1, 7, 4, 5]
# Successful run 614: [2, 0, 6, 7, 5, 1, 3, 4]
# Successful run 615: [3, 6, 0, 2, 4, 1, 5, 7]
# Successful run 616: [4, 0, 1, 5, 7, 3, 6, 2]
# Successful run 617: [4, 6, 3, 7, 1, 5, 0, 2]
# Successful run 618: [7, 3, 6, 2, 4, 5, 1, 0]
# Successful run 619: [5, 3, 0, 1, 7, 4, 6, 2]
# Successful run 620: [5, 1, 4, 7, 6, 2, 0, 3]
# Successful run 621: [0, 6, 4, 5, 7, 1, 3, 2]
# Successful run 622: [1, 5, 0, 2, 7, 4, 3, 6]
# Successful run 623: [7, 2, 3, 4, 0, 6, 1, 5]
# Successful run 624: [3, 2, 7, 1, 6, 4, 0, 5]
# Successful run 625: [7, 4, 6, 5, 3, 1, 2, 0]
# Successful run 626: [6, 7, 3, 0, 2, 4, 5, 1]
# Successful run 627: [7, 2, 6, 1, 0, 5, 3, 4]
# Successful run 628: [5, 2, 7, 3, 4, 0, 6, 1]
# Successful run 629: [1, 3, 2, 7, 0, 4, 6, 5]
# Successful run 630: [7, 6, 1, 0, 4, 5, 2, 3]
# Successful run 631: [6, 0, 4, 5, 3, 1, 2, 7]
# Successful run 632: [2, 0, 4, 5, 3, 7, 6, 1]
# Successful run 633: [6, 4, 7, 3, 1, 0, 5, 2]
# Successful run 634: [3, 6, 0, 5, 2, 1, 7, 4]
# Successful run 635: [6, 2, 5, 3, 4, 7, 1, 0]
# Successful run 636: [0, 7, 3, 1, 4, 2, 5, 6]
# Successful run 637: [5, 2, 6, 3, 0, 1, 7, 4]
# Successful run 638: [2, 5, 0, 1, 3, 6, 7, 4]
# Successful run 639: [7, 0, 2, 5, 6, 4, 3, 1]
# Successful run 640: [2, 5, 0, 3, 6, 1, 4, 7]
# Successful run 641: [1, 4, 3, 6, 7, 0, 5, 2]
# Successful run 642: [4, 6, 5, 1, 2, 3, 7, 0]
# Successful run 643: [6, 7, 5, 2, 1, 0, 4, 3]
# Successful run 644: [3, 2, 6, 4, 1, 0, 7, 5]
# Successful run 645: [5, 2, 4, 1, 7, 6, 3, 0]
# Successful run 646: [1, 0, 4, 3, 7, 5, 6, 2]
# Successful run 647: [4, 7, 1, 2, 6, 0, 5, 3]
# Successful run 648: [5, 4, 0, 1, 6, 3, 7, 2]
# Successful run 649: [4, 0, 5, 1, 2, 3, 7, 6]
# Successful run 650: [0, 2, 3, 6, 5, 4, 1, 7]
# Successful run 651: [6, 1, 5, 7, 3, 0, 4, 2]
# Successful run 652: [0, 7, 2, 1, 4, 3, 6, 5]
# Successful run 653: [4, 5, 2, 1, 0, 3, 6, 7]
# Successful run 654: [1, 6, 7, 3, 0, 5, 4, 2]
# Successful run 655: [1, 2, 6, 7, 5, 4, 3, 0]
# Successful run 656: [3, 2, 6, 1, 7, 5, 0, 4]
# Successful run 657: [3, 1, 5, 6, 7, 0, 2, 4]
# Successful run 658: [5, 7, 6, 1, 2, 3, 4, 0]
# Successful run 659: [2, 6, 4, 7, 1, 0, 5, 3]
# Successful run 660: [5, 7, 6, 3, 1, 4, 0, 2]
# Successful run 661: [7, 1, 4, 2, 3, 0, 5, 6]
# Successful run 662: [7, 2, 0, 4, 3, 1, 6, 5]
# Successful run 663: [7, 3, 6, 2, 0, 4, 5, 1]
# Successful run 664: [6, 3, 0, 5, 7, 1, 2, 4]
# Successful run 665: [5, 1, 0, 3, 7, 2, 4, 6]
# Successful run 666: [2, 6, 0, 5, 3, 4, 1, 7]
# Successful run 667: [0, 4, 3, 7, 5, 1, 2, 6]
# Successful run 668: [7, 2, 6, 0, 1, 3, 5, 4]
# Successful run 669: [0, 7, 4, 3, 1, 6, 2, 5]
# Successful run 670: [1, 7, 2, 3, 5, 4, 0, 6]
# Successful run 671: [7, 2, 0, 6, 5, 3, 1, 4]
# Successful run 672: [4, 6, 1, 3, 7, 5, 2, 0]
# Successful run 673: [6, 3, 0, 4, 7, 1, 2, 5]
# Successful run 674: [4, 0, 6, 3, 2, 1, 7, 5]
# Successful run 675: [1, 5, 3, 7, 2, 4, 0, 6]
# Successful run 676: [3, 1, 7, 0, 4, 2, 6, 5]
# Successful run 677: [1, 4, 3, 0, 2, 7, 5, 6]
# Successful run 678: [6, 3, 1, 0, 5, 2, 4, 7]
# Successful run 679: [6, 4, 5, 2, 3, 0, 7, 1]
# Successful run 680: [7, 5, 6, 1, 0, 4, 2, 3]
# Successful run 681: [7, 2, 3, 1, 4, 0, 6, 5]
# Successful run 682: [3, 6, 5, 0, 2, 1, 7, 4]
# Successful run 683: [2, 6, 0, 5, 7, 3, 1, 4]
# Successful run 684: [2, 3, 4, 5, 0, 1, 6, 7]
# Successful run 685: [4, 7, 5, 1, 0, 2, 6, 3]
# Successful run 686: [7, 2, 5, 0, 3, 6, 4, 1]
# Successful run 687: [3, 2, 4, 7, 0, 5, 1, 6]
# Successful run 688: [4, 5, 1, 6, 2, 3, 7, 0]
# Successful run 689: [4, 2, 1, 0, 7, 6, 3, 5]
# Successful run 690: [2, 0, 3, 7, 6, 5, 1, 4]
# Successful run 691: [4, 3, 2, 6, 7, 1, 0, 5]
# Successful run 692: [1, 7, 0, 5, 2, 3, 4, 6]
# Successful run 693: [3, 6, 4, 7, 2, 5, 0, 1]
# Successful run 694: [2, 7, 3, 1, 6, 0, 4, 5]
# Successful run 695: [0, 3, 5, 6, 7, 2, 1, 4]
# Successful run 696: [0, 5, 1, 7, 3, 6, 2, 4]
# Successful run 697: [5, 0, 2, 1, 6, 3, 4, 7]
# Successful run 698: [4, 1, 3, 5, 6, 0, 7, 2]
# Successful run 699: [2, 6, 5, 7, 4, 0, 3, 1]
# Successful run 700: [5, 0, 6, 7, 4, 1, 3, 2]
# Successful run 701: [2, 0, 7, 1, 3, 6, 4, 5]
# Successful run 702: [4, 2, 3, 7, 6, 0, 1, 5]
# Successful run 703: [0, 3, 6, 7, 4, 1, 2, 5]
# Successful run 704: [6, 5, 2, 4, 0, 3, 7, 1]
# Successful run 705: [4, 2, 1, 7, 6, 3, 0, 5]
# Successful run 706: [3, 4, 1, 0, 2, 7, 6, 5]
# Successful run 707: [0, 4, 5, 2, 1, 7, 3, 6]
# Successful run 708: [2, 5, 0, 6, 1, 7, 3, 4]
# Successful run 709: [3, 6, 2, 7, 5, 4, 0, 1]
# Successful run 710: [3, 6, 5, 0, 1, 2, 7, 4]
# Successful run 711: [5, 7, 1, 2, 4, 3, 6, 0]
# Successful run 712: [4, 1, 5, 2, 7, 3, 0, 6]
# Successful run 713: [2, 1, 7, 5, 6, 0, 4, 3]
# Successful run 714: [6, 5, 0, 4, 2, 7, 3, 1]
# Successful run 715: [7, 6, 3, 4, 2, 5, 0, 1]
# Successful run 716: [6, 7, 3, 1, 2, 0, 5, 4]
# Successful run 717: [0, 1, 6, 3, 5, 7, 2, 4]
# Successful run 718: [2, 0, 6, 1, 5, 7, 3, 4]
# Successful run 719: [2, 6, 3, 1, 7, 4, 0, 5]
# Successful run 720: [6, 3, 5, 1, 4, 2, 0, 7]
# Successful run 721: [1, 5, 3, 7, 2, 0, 6, 4]
# Successful run 722: [7, 5, 4, 0, 2, 3, 6, 1]
# Successful run 723: [2, 3, 0, 7, 1, 5, 4, 6]
# Successful run 724: [0, 6, 4, 5, 3, 2, 7, 1]
# Successful run 725: [2, 5, 3, 4, 0, 1, 7, 6]
# Successful run 726: [0, 3, 2, 6, 5, 1, 4, 7]
# Successful run 727: [1, 2, 0, 3, 6, 7, 5, 4]
# Successful run 728: [0, 1, 2, 6, 4, 5, 3, 7]
# Successful run 729: [5, 7, 3, 0, 6, 1, 4, 2]
# Successful run 730: [5, 7, 4, 3, 1, 0, 2, 6]
# Successful run 731: [0, 3, 6, 1, 7, 2, 5, 4]
# Successful run 732: [2, 0, 4, 3, 7, 6, 1, 5]
# Successful run 733: [7, 2, 3, 5, 1, 0, 6, 4]
# Successful run 734: [4, 1, 6, 0, 2, 5, 7, 3]
# Successful run 735: [0, 5, 1, 4, 3, 6, 7, 2]
# Successful run 736: [4, 5, 2, 7, 6, 1, 3, 0]
# Successful run 737: [7, 2, 0, 5, 4, 3, 6, 1]
# Successful run 738: [7, 0, 4, 2, 3, 5, 6, 1]
# Successful run 739: [3, 1, 0, 6, 7, 5, 4, 2]
# Successful run 740: [3, 0, 5, 4, 7, 6, 2, 1]
# Successful run 741: [2, 7, 0, 3, 5, 6, 1, 4]
# Successful run 742: [2, 3, 0, 1, 6, 4, 7, 5]
# Successful run 743: [3, 5, 7, 1, 2, 0, 4, 6]
# Successful run 744: [6, 1, 2, 4, 7, 3, 5, 0]
# Successful run 745: [6, 0, 5, 7, 2, 1, 4, 3]
# Successful run 746: [3, 6, 2, 1, 0, 7, 4, 5]
# Successful run 747: [1, 5, 4, 0, 6, 3, 2, 7]
# Successful run 748: [3, 4, 5, 6, 0, 2, 1, 7]
# Successful run 749: [5, 2, 4, 6, 7, 1, 3, 0]
# Successful run 750: [3, 6, 2, 4, 1, 0, 5, 7]
# Successful run 751: [5, 2, 0, 4, 1, 7, 3, 6]
# Successful run 752: [0, 6, 5, 1, 7, 3, 2, 4]
# Successful run 753: [5, 3, 0, 4, 2, 6, 7, 1]
# Successful run 754: [0, 2, 1, 5, 4, 7, 3, 6]
# Successful run 755: [2, 0, 7, 1, 5, 3, 6, 4]
# Successful run 756: [7, 0, 5, 2, 4, 1, 6, 3]
# Successful run 757: [7, 0, 6, 1, 3, 4, 5, 2]
# Successful run 758: [1, 3, 0, 4, 2, 5, 7, 6]
# Successful run 759: [2, 3, 4, 6, 1, 7, 0, 5]
# Successful run 760: [2, 3, 7, 6, 5, 0, 4, 1]
# Successful run 761: [5, 3, 2, 1, 7, 4, 0, 6]
# Successful run 762: [6, 5, 0, 7, 3, 1, 2, 4]
# Successful run 763: [7, 5, 3, 0, 1, 2, 4, 6]
# Successful run 764: [0, 7, 1, 4, 6, 2, 3, 5]
# Successful run 765: [3, 2, 6, 4, 0, 5, 7, 1]
# Successful run 766: [7, 4, 5, 1, 0, 3, 2, 6]
# Successful run 767: [6, 0, 1, 3, 2, 5, 4, 7]
# Successful run 768: [2, 4, 0, 3, 6, 5, 7, 1]
# Successful run 769: [2, 6, 0, 7, 1, 5, 4, 3]
# Successful run 770: [5, 3, 1, 6, 4, 2, 0, 7]
# Successful run 771: [0, 7, 5, 3, 1, 2, 6, 4]
# Successful run 772: [4, 0, 6, 1, 5, 2, 7, 3]
# Successful run 773: [4, 2, 0, 7, 5, 6, 3, 1]
# Successful run 774: [6, 5, 1, 7, 2, 4, 0, 3]
# Successful run 775: [0, 5, 6, 3, 2, 1, 7, 4]
# Successful run 776: [2, 1, 5, 6, 4, 0, 7, 3]
# Successful run 777: [7, 2, 3, 4, 0, 1, 5, 6]
# Successful run 778: [0, 4, 3, 1, 6, 2, 7, 5]
# Successful run 779: [2, 3, 6, 1, 0, 7, 4, 5]
# Successful run 780: [7, 2, 3, 1, 5, 0, 4, 6]
# Successful run 781: [7, 4, 0, 3, 1, 2, 5, 6]
# Successful run 782: [7, 4, 2, 6, 3, 5, 0, 1]
# Successful run 783: [3, 0, 1, 5, 4, 2, 7, 6]
# Successful run 784: [6, 7, 3, 2, 5, 0, 4, 1]
# Successful run 785: [2, 1, 3, 7, 6, 5, 0, 4]
# Successful run 786: [5, 3, 0, 4, 2, 6, 7, 1]
# Successful run 787: [1, 5, 6, 3, 4, 2, 0, 7]
# Successful run 788: [3, 4, 2, 5, 7, 6, 1, 0]
# Successful run 789: [0, 3, 2, 6, 1, 7, 4, 5]
# Successful run 790: [5, 1, 3, 4, 7, 2, 6, 0]
# Successful run 791: [1, 2, 7, 0, 6, 5, 3, 4]
# Successful run 792: [6, 1, 4, 3, 7, 5, 0, 2]
# Successful run 793: [0, 6, 1, 2, 4, 3, 5, 7]
# Successful run 794: [5, 2, 4, 7, 1, 0, 3, 6]
# Successful run 795: [4, 1, 5, 0, 2, 6, 3, 7]
# Successful run 796: [2, 7, 3, 4, 0, 6, 5, 1]
# Successful run 797: [1, 4, 3, 0, 5, 6, 2, 7]
# Successful run 798: [1, 7, 4, 5, 0, 6, 3, 2]
# Successful run 799: [6, 5, 2, 1, 3, 0, 7, 4]
# Successful run 800: [6, 5, 3, 4, 1, 0, 2, 7]
# Successful run 801: [0, 4, 3, 7, 5, 6, 1, 2]
# Successful run 802: [1, 2, 5, 0, 3, 4, 6, 7]
# Successful run 803: [7, 2, 4, 6, 1, 0, 5, 3]
# Successful run 804: [1, 0, 3, 5, 6, 2, 4, 7]
# Successful run 805: [0, 4, 6, 7, 2, 5, 1, 3]
# Successful run 806: [4, 2, 5, 0, 6, 1, 7, 3]
# Successful run 807: [4, 1, 5, 0, 7, 3, 6, 2]
# Successful run 808: [4, 1, 6, 7, 3, 0, 5, 2]
# Successful run 809: [6, 5, 2, 3, 7, 4, 1, 0]
# Successful run 810: [1, 2, 4, 5, 3, 0, 7, 6]
# Successful run 811: [1, 3, 7, 6, 2, 0, 5, 4]
# Successful run 812: [5, 4, 3, 0, 1, 7, 2, 6]
# Successful run 813: [2, 7, 4, 3, 0, 6, 1, 5]
# Successful run 814: [3, 5, 0, 4, 1, 7, 6, 2]
# Successful run 815: [1, 4, 2, 6, 7, 3, 5, 0]
# Successful run 816: [6, 5, 1, 3, 0, 7, 4, 2]
# Successful run 817: [5, 0, 6, 4, 7, 1, 2, 3]
# Successful run 818: [3, 1, 5, 0, 2, 6, 4, 7]
# Successful run 819: [0, 4, 2, 3, 1, 6, 5, 7]
# Successful run 820: [7, 4, 0, 2, 1, 3, 6, 5]
# Successful run 821: [4, 1, 2, 3, 6, 0, 7, 5]
# Successful run 822: [0, 7, 5, 4, 6, 2, 3, 1]
# Successful run 823: [1, 7, 0, 3, 6, 5, 4, 2]
# Successful run 824: [1, 2, 6, 5, 7, 4, 0, 3]
# Successful run 825: [5, 3, 1, 4, 0, 6, 7, 2]
# Successful run 826: [3, 5, 2, 0, 7, 6, 4, 1]
# Successful run 827: [6, 0, 3, 4, 1, 2, 7, 5]
# Successful run 828: [5, 3, 0, 1, 4, 2, 7, 6]
# Successful run 829: [4, 0, 7, 3, 5, 6, 2, 1]
# Successful run 830: [2, 6, 1, 3, 5, 4, 7, 0]
# Successful run 831: [2, 4, 5, 6, 7, 0, 3, 1]
# Successful run 832: [0, 3, 7, 1, 2, 5, 6, 4]
# Successful run 833: [0, 3, 2, 4, 6, 5, 7, 1]
# Successful run 834: [1, 3, 7, 6, 0, 4, 2, 5]
# Successful run 835: [0, 3, 5, 4, 2, 7, 1, 6]
# Successful run 836: [3, 5, 0, 2, 1, 7, 4, 6]
# Successful run 837: [5, 2, 4, 0, 6, 7, 1, 3]
# Successful run 838: [2, 3, 1, 5, 4, 6, 7, 0]
# Successful run 839: [6, 2, 4, 0, 1, 5, 7, 3]
# Successful run 840: [7, 1, 2, 3, 6, 4, 5, 0]
# Successful run 841: [6, 7, 3, 1, 5, 0, 2, 4]
# Successful run 842: [0, 3, 2, 5, 4, 6, 7, 1]
# Successful run 843: [2, 0, 7, 3, 6, 1, 4, 5]
# Successful run 844: [7, 4, 3, 5, 6, 2, 0, 1]
# Successful run 845: [1, 2, 7, 5, 3, 0, 6, 4]
# Successful run 846: [6, 7, 4, 1, 3, 0, 2, 5]
# Successful run 847: [7, 6, 5, 3, 1, 4, 0, 2]
# Successful run 848: [7, 0, 6, 1, 3, 5, 2, 4]
# Successful run 849: [6, 2, 0, 5, 4, 1, 3, 7]
# Successful run 850: [4, 5, 6, 7, 0, 3, 2, 1]
# Successful run 851: [2, 1, 0, 7, 5, 4, 3, 6]
# Successful run 852: [7, 6, 4, 0, 1, 3, 5, 2]
# Successful run 853: [0, 4, 6, 5, 2, 3, 7, 1]
# Successful run 854: [3, 2, 5, 0, 4, 6, 1, 7]
# Successful run 855: [7, 3, 4, 6, 5, 0, 1, 2]
# Successful run 856: [6, 1, 5, 3, 0, 2, 7, 4]
# Successful run 857: [6, 7, 5, 3, 1, 4, 0, 2]
# Successful run 858: [5, 0, 3, 2, 1, 4, 7, 6]
# Successful run 859: [3, 6, 5, 2, 0, 1, 4, 7]
# Successful run 860: [3, 7, 2, 1, 5, 4, 0, 6]
# Successful run 861: [1, 4, 5, 7, 3, 6, 2, 0]
# Successful run 862: [2, 7, 4, 5, 1, 0, 6, 3]
# Successful run 863: [6, 2, 1, 5, 3, 4, 7, 0]
# Successful run 864: [6, 4, 5, 2, 7, 0, 3, 1]
# Successful run 865: [4, 3, 5, 2, 6, 1, 0, 7]
# Successful run 866: [2, 3, 6, 4, 0, 1, 5, 7]
# Successful run 867: [5, 4, 0, 1, 3, 7, 6, 2]
# Successful run 868: [1, 7, 4, 5, 0, 3, 6, 2]
# Successful run 869: [3, 1, 7, 4, 5, 6, 0, 2]
# Successful run 870: [6, 1, 4, 7, 2, 3, 0, 5]
# Successful run 871: [5, 4, 3, 2, 0, 1, 7, 6]
# Successful run 872: [7, 2, 6, 5, 0, 3, 4, 1]
# Successful run 873: [7, 2, 6, 3, 0, 4, 5, 1]
# Successful run 874: [7, 5, 2, 1, 3, 0, 6, 4]
# Successful run 875: [6, 2, 1, 0, 5, 3, 7, 4]
# Successful run 876: [2, 4, 3, 1, 0, 5, 7, 6]
# Successful run 877: [0, 2, 6, 3, 7, 1, 5, 4]
# Successful run 878: [4, 6, 7, 1, 3, 2, 0, 5]
# Successful run 879: [4, 3, 7, 2, 6, 0, 5, 1]
# Successful run 880: [0, 1, 7, 6, 2, 5, 4, 3]
# Successful run 881: [2, 5, 4, 0, 7, 1, 3, 6]
# Successful run 882: [7, 6, 0, 4, 5, 1, 3, 2]
# Successful run 883: [5, 2, 7, 6, 3, 1, 4, 0]
# Successful run 884: [6, 4, 1, 0, 3, 7, 2, 5]
# Successful run 885: [2, 0, 3, 7, 6, 5, 4, 1]
# Successful run 886: [7, 3, 5, 4, 2, 1, 0, 6]
# Successful run 887: [2, 0, 3, 6, 1, 4, 7, 5]
# Successful run 888: [5, 2, 6, 3, 0, 7, 4, 1]
# Successful run 889: [1, 2, 4, 5, 3, 6, 7, 0]
# Successful run 890: [3, 7, 6, 4, 0, 2, 5, 1]
# Successful run 891: [2, 3, 1, 0, 7, 4, 6, 5]
# Successful run 892: [3, 5, 2, 4, 1, 7, 0, 6]
# Successful run 893: [0, 5, 7, 6, 3, 1, 4, 2]
# Successful run 894: [4, 5, 3, 2, 0, 6, 7, 1]
# Successful run 895: [2, 1, 0, 6, 7, 5, 4, 3]
# Successful run 896: [5, 0, 6, 4, 3, 7, 1, 2]
# Successful run 897: [3, 6, 5, 2, 0, 7, 1, 4]
# Successful run 898: [1, 3, 5, 0, 4, 6, 7, 2]
# Successful run 899: [1, 5, 7, 3, 6, 2, 0, 4]
# Successful run 900: [4, 7, 6, 0, 3, 5, 2, 1]
# Successful run 901: [7, 4, 2, 5, 0, 6, 1, 3]
# Successful run 902: [6, 2, 5, 0, 3, 4, 7, 1]
# Successful run 903: [3, 5, 2, 7, 1, 0, 4, 6]
# Successful run 904: [1, 5, 4, 2, 0, 3, 6, 7]
# Successful run 905: [3, 1, 6, 7, 0, 4, 5, 2]
# Successful run 906: [6, 3, 2, 5, 0, 1, 4, 7]
# Successful run 907: [0, 7, 3, 1, 2, 5, 4, 6]
# Successful run 908: [7, 3, 1, 2, 6, 0, 4, 5]
# Successful run 909: [7, 2, 0, 5, 1, 4, 3, 6]
# Successful run 910: [5, 0, 7, 3, 2, 4, 6, 1]
# Successful run 911: [0, 1, 2, 5, 6, 4, 7, 3]
# Successful run 912: [4, 3, 5, 2, 6, 1, 7, 0]
# Successful run 913: [2, 6, 4, 7, 1, 5, 0, 3]
# Successful run 914: [3, 6, 0, 2, 1, 5, 7, 4]
# Successful run 915: [1, 5, 3, 7, 6, 2, 0, 4]
# Successful run 916: [1, 4, 5, 2, 3, 7, 0, 6]
# Successful run 917: [6, 1, 0, 2, 7, 3, 4, 5]
# Successful run 918: [3, 7, 5, 0, 2, 6, 4, 1]
# Successful run 919: [7, 5, 4, 6, 0, 3, 1, 2]
# Successful run 920: [4, 6, 2, 5, 1, 3, 7, 0]
# Successful run 921: [3, 1, 5, 0, 7, 2, 4, 6]
# Successful run 922: [0, 6, 2, 5, 3, 7, 4, 1]
# Successful run 923: [3, 7, 1, 5, 2, 6, 4, 0]
# Successful run 924: [3, 1, 7, 2, 0, 5, 6, 4]
# Successful run 925: [7, 2, 0, 3, 6, 4, 5, 1]
# Successful run 926: [2, 6, 5, 4, 7, 3, 1, 0]
# Successful run 927: [0, 2, 7, 6, 4, 3, 1, 5]
# Successful run 928: [6, 5, 2, 7, 0, 1, 4, 3]
# Successful run 929: [3, 2, 6, 0, 7, 1, 5, 4]
# Successful run 930: [0, 1, 2, 6, 4, 7, 5, 3]
# Successful run 931: [4, 2, 5, 3, 6, 7, 1, 0]
# Successful run 932: [3, 2, 7, 0, 4, 1, 5, 6]
# Successful run 933: [0, 7, 4, 3, 2, 5, 6, 1]
# Successful run 934: [5, 6, 3, 4, 1, 2, 0, 7]
# Successful run 935: [4, 1, 0, 6, 2, 3, 5, 7]
# Successful run 936: [2, 4, 3, 5, 7, 1, 6, 0]
# Successful run 937: [2, 1, 0, 7, 3, 4, 5, 6]
# Successful run 938: [5, 2, 4, 1, 0, 3, 7, 6]
# Successful run 939: [3, 4, 2, 1, 0, 5, 7, 6]
# Successful run 940: [3, 5, 7, 6, 2, 4, 1, 0]
# Successful run 941: [7, 2, 3, 1, 0, 5, 4, 6]
# Successful run 942: [4, 1, 3, 6, 2, 5, 0, 7]
# Successful run 943: [0, 7, 6, 5, 1, 4, 2, 3]
# Successful run 944: [3, 2, 6, 7, 0, 4, 5, 1]
# Successful run 945: [2, 0, 7, 1, 6, 3, 4, 5]
# Successful run 946: [4, 0, 7, 2, 6, 5, 3, 1]
# Successful run 947: [4, 2, 6, 7, 0, 3, 1, 5]
# Successful run 948: [0, 5, 1, 2, 6, 7, 4, 3]
# Successful run 949: [3, 6, 7, 0, 2, 4, 1, 5]
# Successful run 950: [5, 2, 7, 3, 1, 0, 4, 6]
# Successful run 951: [5, 2, 6, 0, 4, 3, 7, 1]
# Successful run 952: [1, 6, 5, 2, 0, 3, 4, 7]
# Successful run 953: [0, 7, 1, 4, 5, 3, 2, 6]
# Successful run 954: [3, 2, 0, 4, 6, 7, 1, 5]
# Successful run 955: [2, 6, 1, 5, 3, 7, 4, 0]
# Successful run 956: [6, 7, 5, 3, 0, 4, 1, 2]
# Successful run 957: [1, 0, 5, 7, 2, 3, 4, 6]
# Successful run 958: [2, 3, 6, 0, 1, 4, 7, 5]
# Successful run 959: [2, 5, 7, 6, 4, 3, 0, 1]
# Successful run 960: [0, 7, 5, 1, 3, 2, 4, 6]
# Successful run 961: [0, 3, 5, 7, 4, 1, 2, 6]
# Successful run 962: [7, 0, 5, 2, 6, 4, 1, 3]
# Successful run 963: [5, 0, 6, 2, 7, 3, 1, 4]
# Successful run 964: [4, 7, 6, 3, 2, 1, 0, 5]
# Successful run 965: [0, 2, 5, 7, 1, 6, 4, 3]
# Successful run 966: [3, 6, 1, 7, 2, 4, 5, 0]
# Successful run 967: [7, 1, 6, 4, 2, 3, 5, 0]
# Successful run 968: [0, 7, 2, 6, 1, 5, 4, 3]
# Successful run 969: [7, 4, 5, 3, 1, 0, 6, 2]
# Successful run 970: [7, 6, 1, 5, 2, 3, 0, 4]
# Successful run 971: [2, 1, 5, 4, 7, 6, 0, 3]
# Successful run 972: [3, 5, 2, 7, 4, 6, 0, 1]
# Successful run 973: [0, 6, 4, 1, 5, 3, 2, 7]
# Successful run 974: [5, 7, 1, 6, 0, 2, 4, 3]
# Successful run 975: [7, 3, 4, 6, 5, 0, 1, 2]
# Successful run 976: [1, 2, 0, 3, 4, 5, 7, 6]
# Successful run 977: [2, 3, 4, 5, 0, 1, 7, 6]
# Successful run 978: [3, 2, 4, 7, 0, 6, 1, 5]
# Successful run 979: [5, 1, 2, 6, 0, 7, 4, 3]
# Successful run 980: [6, 7, 3, 5, 4, 2, 1, 0]
# Successful run 981: [2, 4, 5, 7, 3, 1, 0, 6]
# Successful run 982: [5, 3, 2, 6, 4, 1, 0, 7]
# Successful run 983: [6, 4, 5, 0, 7, 2, 1, 3]
# Successful run 984: [2, 1, 4, 3, 7, 5, 0, 6]
# Successful run 985: [4, 7, 1, 2, 6, 5, 0, 3]
# Successful run 986: [4, 7, 5, 2, 3, 6, 0, 1]
# Successful run 987: [1, 2, 7, 3, 6, 0, 4, 5]
# Successful run 988: [6, 2, 0, 5, 7, 4, 3, 1]
# Successful run 989: [5, 1, 3, 2, 6, 7, 4, 0]
# Successful run 990: [1, 4, 6, 3, 5, 2, 7, 0]
# Successful run 991: [1, 0, 7, 5, 4, 3, 6, 2]
# Successful run 992: [3, 5, 6, 2, 0, 7, 1, 4]
# Successful run 993: [5, 2, 7, 1, 0, 3, 6, 4]
# Successful run 994: [0, 6, 4, 1, 7, 2, 5, 3]
# Successful run 995: [7, 4, 0, 2, 6, 5, 1, 3]
# Successful run 996: [4, 6, 1, 2, 0, 5, 3, 7]
# Successful run 997: [4, 7, 3, 5, 0, 1, 2, 6]
# Successful run 998: [6, 4, 2, 5, 3, 0, 7, 1]
# Successful run 999: [3, 0, 5, 7, 2, 4, 1, 6]
# Successful run 1000: [0, 2, 5, 7, 1, 3, 6, 4]
# Success rate: 1000 out of 1000
# Average steps when successful: 0.0
# No unsuccessful runs.
# Succeeded 1000 times out of 1000 runs.
# Failed 0 times out of 1000 runs.

# %%
import random

def is_valid(board):
    n = len(board)
    for i in range(n):
        for j in range(i+1, n):
            if board[i] == board[j] or abs(board[i] - board[j]) == j - i:
                return False
    return True

def steepest_ascent_hill_climbing_with_sideways(n, max_sideways_moves, max_steps):
    success_count = 0
    total_steps_success = 0
    total_steps_failure = 0
    steps_list = []

    for _ in range(1000):
        # Create a more challenging starting configuration
        board = list(range(n))
        random.shuffle(board)
        steps = 0

        while steps < max_steps:
            current_attacks = sum([board.count(board[i]) - 1 for i in range(n)])
            steps_list.append(steps)

            if current_attacks == 0:
                success_count += 1
                total_steps_success += steps
                print(f"Successful run {success_count}: {board}")
                break

            best_board = list(board)
            best_attacks = current_attacks
            sideways_moves = 0

            for i in range(n):
                for j in range(n):
                    board[i] = j
                    new_attacks = sum([board.count(board[k]) - 1 for k in range(n)])

                    if new_attacks < best_attacks:
                        best_board = list(board)
                        best_attacks = new_attacks
                        sideways_moves = 0
                    elif new_attacks == best_attacks and sideways_moves < max_sideways_moves:
                        # Perform a sideways move
                        best_board = list(board)
                        sideways_moves += 1

                    board[i] = best_board[i]

            if best_attacks >= current_attacks:
                print(f"Unsuccessful run {1000 - success_count}: {board}")
                break

            board = list(best_board)
            steps += 1
        else:
            # The loop completed without finding a solution, mark as unsuccessful
            total_steps_failure += max_steps
            print(f"Unsuccessful run {1000 - success_count}: {board}")

    return success_count, steps_list, total_steps_failure

if __name__ == "__main__":
    n = 8  # Change this to the desired number of queens
    max_sideways_moves = 3  # Set the maximum number of sideways moves
    max_steps = 50  # Set the maximum number of steps to simulate failures
    success_count, steps_list, total_steps_failure = steepest_ascent_hill_climbing_with_sideways(n, max_sideways_moves, max_steps)
    print(f"Success rate: {success_count} out of 1000")

    if success_count > 0:
        avg_steps_success = total_steps_success / success_count
    else:
        print("No successful runs.")

    if success_count < 1000:
        avg_steps_failure = total_steps_failure / (1000 - success_count)
        print(f"Average steps when unsuccessful: {avg_steps_failure}")
        print(f"Unsuccessful runs steps list: {steps_list[success_count:]}")
    else:
        print("No unsuccessful runs.")

    print(f"Succeeded {success_count} times out of 1000 runs.")
    print(f"Failed {1000 - success_count} times out of 1000 runs.")
# Out:
# Successful run 1: [0, 4, 2, 1, 3, 7, 6, 5]
# Successful run 2: [7, 0, 5, 1, 4, 3, 6, 2]
# Successful run 3: [1, 5, 4, 7, 3, 2, 0, 6]
# Successful run 4: [5, 4, 3, 1, 0, 7, 6, 2]
# Successful run 5: [0, 6, 5, 4, 3, 2, 1, 7]
# Successful run 6: [4, 6, 0, 7, 1, 3, 5, 2]
# Successful run 7: [4, 2, 7, 1, 5, 6, 0, 3]
# Successful run 8: [2, 0, 7, 4, 6, 3, 5, 1]
# Successful run 9: [5, 1, 4, 6, 3, 0, 2, 7]
# Successful run 10: [4, 5, 6, 3, 2, 0, 1, 7]
# Successful run 11: [6, 3, 7, 5, 4, 2, 0, 1]
# Successful run 12: [4, 7, 5, 0, 6, 3, 2, 1]
# Successful run 13: [6, 4, 5, 7, 3, 0, 1, 2]
# Successful run 14: [4, 3, 2, 0, 5, 6, 7, 1]
# Successful run 15: [0, 1, 4, 6, 5, 7, 2, 3]
# Successful run 16: [5, 1, 6, 3, 7, 2, 0, 4]
# Successful run 17: [5, 6, 4, 1, 0, 3, 7, 2]
# Successful run 18: [1, 2, 7, 3, 0, 4, 6, 5]
# Successful run 19: [2, 7, 1, 5, 3, 6, 0, 4]
# Successful run 20: [7, 0, 1, 5, 6, 3, 4, 2]
# Successful run 21: [3, 4, 5, 7, 6, 2, 1, 0]
# Successful run 22: [2, 0, 5, 4, 3, 7, 6, 1]
# Successful run 23: [7, 0, 4, 5, 6, 1, 3, 2]
# Successful run 24: [6, 0, 2, 3, 4, 5, 7, 1]
# Successful run 25: [3, 4, 6, 0, 2, 1, 7, 5]
# Successful run 26: [5, 1, 0, 7, 6, 4, 2, 3]
# Successful run 27: [1, 2, 0, 5, 3, 6, 4, 7]
# Successful run 28: [7, 1, 2, 6, 5, 0, 3, 4]
# Successful run 29: [4, 6, 0, 3, 5, 1, 7, 2]
# Successful run 30: [2, 0, 5, 1, 4, 7, 6, 3]
# Successful run 31: [1, 6, 2, 5, 7, 4, 0, 3]
# Successful run 32: [3, 5, 1, 6, 2, 4, 7, 0]
# Successful run 33: [1, 7, 6, 0, 5, 2, 3, 4]
# Successful run 34: [1, 0, 4, 3, 7, 6, 2, 5]
# Successful run 35: [6, 3, 1, 7, 4, 5, 2, 0]
# Successful run 36: [0, 6, 5, 4, 2, 1, 3, 7]
# Successful run 37: [0, 4, 7, 3, 1, 5, 6, 2]
# Successful run 38: [7, 0, 4, 1, 3, 2, 6, 5]
# Successful run 39: [0, 3, 1, 5, 4, 7, 2, 6]
# Successful run 40: [3, 4, 1, 7, 5, 2, 0, 6]
# Successful run 41: [4, 1, 6, 5, 3, 2, 0, 7]
# Successful run 42: [7, 5, 4, 1, 6, 0, 2, 3]
# Successful run 43: [1, 5, 2, 6, 4, 0, 7, 3]
# Successful run 44: [4, 6, 2, 0, 5, 1, 3, 7]
# Successful run 45: [0, 2, 5, 3, 4, 7, 6, 1]
# Successful run 46: [3, 2, 6, 5, 7, 0, 1, 4]
# Successful run 47: [5, 4, 0, 6, 2, 1, 7, 3]
# Successful run 48: [0, 7, 3, 4, 1, 2, 5, 6]
# Successful run 49: [3, 5, 1, 7, 4, 2, 6, 0]
# Successful run 50: [5, 6, 2, 4, 3, 7, 1, 0]
# Successful run 51: [3, 2, 7, 1, 5, 4, 0, 6]
# Successful run 52: [6, 1, 0, 5, 3, 2, 4, 7]
# Successful run 53: [6, 4, 2, 5, 0, 1, 7, 3]
# Successful run 54: [4, 3, 0, 7, 2, 6, 5, 1]
# Successful run 55: [2, 6, 7, 5, 4, 3, 1, 0]
# Successful run 56: [3, 0, 6, 4, 2, 5, 7, 1]
# Successful run 57: [2, 4, 6, 5, 0, 1, 7, 3]
# Successful run 58: [7, 5, 2, 1, 6, 4, 3, 0]
# Successful run 59: [4, 1, 0, 3, 2, 5, 7, 6]
# Successful run 60: [1, 0, 6, 2, 5, 3, 4, 7]
# Successful run 61: [1, 4, 3, 0, 2, 5, 6, 7]
# Successful run 62: [0, 6, 5, 7, 4, 1, 2, 3]
# Successful run 63: [6, 0, 3, 7, 2, 5, 4, 1]
# Successful run 64: [4, 0, 1, 2, 6, 3, 5, 7]
# Successful run 65: [3, 0, 4, 1, 7, 2, 6, 5]
# Successful run 66: [5, 4, 2, 0, 3, 7, 6, 1]
# Successful run 67: [0, 5, 2, 1, 6, 4, 3, 7]
# Successful run 68: [4, 6, 3, 0, 5, 7, 2, 1]
# Successful run 69: [6, 3, 0, 7, 1, 4, 5, 2]
# Successful run 70: [0, 4, 1, 6, 3, 7, 2, 5]
# Successful run 71: [5, 2, 1, 6, 3, 7, 0, 4]
# Successful run 72: [5, 0, 7, 4, 2, 6, 3, 1]
# Successful run 73: [5, 6, 4, 3, 7, 1, 0, 2]
# Successful run 74: [4, 6, 1, 5, 2, 7, 0, 3]
# Successful run 75: [2, 7, 0, 4, 1, 6, 3, 5]
# Successful run 76: [0, 7, 6, 4, 5, 1, 2, 3]
# Successful run 77: [1, 3, 5, 7, 0, 6, 4, 2]
# Successful run 78: [2, 0, 5, 1, 7, 6, 4, 3]
# Successful run 79: [2, 7, 4, 5, 6, 1, 3, 0]
# Successful run 80: [1, 2, 5, 3, 0, 6, 4, 7]
# Successful run 81: [2, 0, 5, 1, 7, 4, 6, 3]
# Successful run 82: [5, 1, 4, 7, 2, 3, 6, 0]
# Successful run 83: [2, 4, 3, 6, 5, 7, 0, 1]
# Successful run 84: [2, 5, 7, 0, 3, 4, 6, 1]
# Successful run 85: [1, 2, 3, 5, 0, 4, 6, 7]
# Successful run 86: [6, 3, 4, 0, 5, 1, 7, 2]
# Successful run 87: [7, 6, 0, 5, 1, 3, 4, 2]
# Successful run 88: [3, 7, 0, 1, 2, 5, 6, 4]
# Successful run 89: [1, 5, 4, 3, 7, 2, 0, 6]
# Successful run 90: [4, 6, 0, 3, 7, 5, 1, 2]
# Successful run 91: [6, 4, 2, 0, 5, 7, 1, 3]
# Successful run 92: [1, 0, 5, 7, 3, 6, 2, 4]
# Successful run 93: [7, 2, 3, 6, 0, 5, 4, 1]
# Successful run 94: [6, 1, 7, 3, 0, 2, 5, 4]
# Successful run 95: [0, 4, 6, 2, 1, 7, 5, 3]
# Successful run 96: [0, 6, 4, 2, 3, 7, 5, 1]
# Successful run 97: [2, 4, 3, 1, 7, 6, 5, 0]
# Successful run 98: [2, 4, 5, 1, 3, 0, 6, 7]
# Successful run 99: [3, 4, 0, 6, 2, 1, 7, 5]
# Successful run 100: [0, 3, 5, 4, 1, 6, 7, 2]
# Successful run 101: [4, 5, 0, 2, 6, 7, 3, 1]
# Successful run 102: [3, 2, 6, 0, 7, 4, 5, 1]
# Successful run 103: [4, 5, 2, 1, 0, 7, 3, 6]
# Successful run 104: [0, 2, 5, 7, 3, 1, 6, 4]
# Successful run 105: [2, 1, 6, 0, 7, 4, 3, 5]
# Successful run 106: [3, 5, 0, 2, 6, 7, 1, 4]
# Successful run 107: [1, 7, 0, 4, 3, 2, 6, 5]
# Successful run 108: [5, 1, 3, 7, 2, 6, 0, 4]
# Successful run 109: [5, 4, 7, 6, 3, 1, 2, 0]
# Successful run 110: [3, 1, 4, 2, 0, 5, 7, 6]
# Successful run 111: [2, 7, 6, 0, 4, 3, 1, 5]
# Successful run 112: [7, 0, 4, 1, 6, 5, 3, 2]
# Successful run 113: [7, 2, 1, 4, 0, 3, 6, 5]
# Successful run 114: [5, 3, 0, 1, 4, 6, 7, 2]
# Successful run 115: [4, 1, 7, 3, 6, 0, 2, 5]
# Successful run 116: [7, 2, 5, 0, 4, 6, 3, 1]
# Successful run 117: [1, 5, 2, 3, 4, 0, 6, 7]
# Successful run 118: [2, 7, 1, 6, 3, 0, 5, 4]
# Successful run 119: [1, 0, 6, 7, 3, 2, 5, 4]
# Successful run 120: [5, 2, 3, 6, 7, 1, 0, 4]
# Successful run 121: [5, 7, 6, 2, 3, 0, 1, 4]
# Successful run 122: [6, 5, 2, 4, 0, 1, 3, 7]
# Successful run 123: [1, 6, 3, 4, 7, 2, 5, 0]
# Successful run 124: [3, 6, 0, 7, 5, 4, 1, 2]
# Successful run 125: [5, 6, 0, 1, 2, 7, 4, 3]
# Successful run 126: [3, 4, 5, 6, 0, 1, 7, 2]
# Successful run 127: [3, 6, 7, 4, 2, 5, 1, 0]
# Successful run 128: [4, 3, 5, 1, 2, 0, 6, 7]
# Successful run 129: [4, 0, 5, 2, 6, 7, 3, 1]
# Successful run 130: [5, 1, 4, 3, 2, 0, 6, 7]
# Successful run 131: [2, 7, 5, 1, 0, 4, 6, 3]
# Successful run 132: [4, 1, 2, 7, 5, 3, 6, 0]
# Successful run 133: [5, 4, 7, 1, 6, 2, 3, 0]
# Successful run 134: [6, 1, 4, 2, 0, 5, 7, 3]
# Successful run 135: [6, 1, 2, 4, 3, 5, 7, 0]
# Successful run 136: [3, 5, 0, 4, 6, 2, 7, 1]
# Successful run 137: [1, 0, 4, 5, 7, 6, 3, 2]
# Successful run 138: [7, 5, 3, 0, 6, 4, 1, 2]
# Successful run 139: [2, 5, 6, 7, 0, 3, 1, 4]
# Successful run 140: [3, 2, 0, 1, 6, 4, 5, 7]
# Successful run 141: [4, 1, 3, 7, 5, 6, 0, 2]
# Successful run 142: [0, 7, 4, 5, 6, 2, 1, 3]
# Successful run 143: [5, 1, 6, 4, 7, 0, 2, 3]
# Successful run 144: [1, 7, 4, 0, 6, 5, 2, 3]
# Successful run 145: [6, 1, 3, 5, 2, 0, 4, 7]
# Successful run 146: [5, 1, 6, 4, 2, 7, 3, 0]
# Successful run 147: [2, 3, 7, 4, 1, 5, 6, 0]
# Successful run 148: [5, 1, 0, 4, 7, 6, 3, 2]
# Successful run 149: [3, 5, 0, 1, 7, 4, 2, 6]
# Successful run 150: [1, 5, 4, 3, 6, 0, 2, 7]
# Successful run 151: [0, 3, 4, 7, 2, 1, 6, 5]
# Successful run 152: [0, 4, 1, 2, 6, 3, 5, 7]
# Successful run 153: [4, 0, 5, 6, 3, 2, 7, 1]
# Successful run 154: [2, 4, 3, 0, 1, 6, 5, 7]
# Successful run 155: [1, 7, 3, 6, 0, 2, 4, 5]
# Successful run 156: [6, 3, 1, 5, 7, 0, 2, 4]
# Successful run 157: [1, 2, 6, 3, 4, 7, 0, 5]
# Successful run 158: [6, 7, 5, 0, 1, 3, 4, 2]
# Successful run 159: [7, 3, 6, 1, 4, 5, 0, 2]
# Successful run 160: [5, 0, 2, 1, 7, 3, 6, 4]
# Successful run 161: [7, 4, 5, 3, 6, 1, 0, 2]
# Successful run 162: [2, 4, 6, 5, 1, 7, 3, 0]
# Successful run 163: [5, 0, 6, 1, 3, 7, 2, 4]
# Successful run 164: [6, 2, 7, 4, 1, 0, 3, 5]
# Successful run 165: [2, 4, 7, 5, 6, 1, 0, 3]
# Successful run 166: [2, 1, 6, 5, 4, 7, 0, 3]
# Successful run 167: [0, 4, 5, 6, 3, 7, 2, 1]
# Successful run 168: [7, 4, 2, 6, 5, 3, 0, 1]
# Successful run 169: [5, 1, 7, 2, 3, 6, 4, 0]
# Successful run 170: [0, 3, 6, 1, 4, 7, 5, 2]
# Successful run 171: [1, 3, 5, 2, 4, 6, 0, 7]
# Successful run 172: [7, 3, 5, 6, 2, 1, 4, 0]
# Successful run 173: [4, 6, 2, 0, 1, 3, 7, 5]
# Successful run 174: [2, 1, 0, 4, 7, 5, 3, 6]
# Successful run 175: [1, 4, 5, 6, 3, 0, 2, 7]
# Successful run 176: [5, 7, 4, 6, 3, 1, 2, 0]
# Successful run 177: [5, 4, 7, 2, 1, 0, 6, 3]
# Successful run 178: [1, 2, 0, 6, 4, 7, 5, 3]
# Successful run 179: [7, 2, 0, 6, 4, 5, 1, 3]
# Successful run 180: [1, 0, 4, 3, 7, 5, 6, 2]
# Successful run 181: [7, 2, 4, 5, 6, 3, 0, 1]
# Successful run 182: [7, 0, 1, 4, 6, 2, 5, 3]
# Successful run 183: [6, 4, 3, 0, 1, 2, 5, 7]
# Successful run 184: [5, 2, 0, 3, 7, 6, 1, 4]
# Successful run 185: [5, 2, 0, 1, 4, 7, 6, 3]
# Successful run 186: [5, 0, 2, 7, 1, 4, 6, 3]
# Successful run 187: [4, 2, 3, 7, 0, 1, 6, 5]
# Successful run 188: [2, 5, 6, 1, 3, 7, 4, 0]
# Successful run 189: [2, 1, 7, 5, 3, 4, 0, 6]
# Successful run 190: [6, 7, 5, 0, 2, 1, 4, 3]
# Successful run 191: [0, 1, 3, 4, 5, 7, 2, 6]
# Successful run 192: [2, 6, 5, 1, 0, 7, 4, 3]
# Successful run 193: [4, 1, 3, 7, 6, 0, 5, 2]
# Successful run 194: [1, 4, 6, 7, 3, 5, 2, 0]
# Successful run 195: [0, 7, 5, 6, 3, 1, 2, 4]
# Successful run 196: [5, 7, 4, 1, 6, 0, 3, 2]
# Successful run 197: [3, 2, 0, 4, 7, 5, 6, 1]
# Successful run 198: [1, 0, 5, 2, 7, 6, 4, 3]
# Successful run 199: [2, 6, 4, 7, 1, 5, 0, 3]
# Successful run 200: [4, 5, 7, 3, 2, 1, 6, 0]
# Successful run 201: [2, 6, 0, 3, 1, 7, 5, 4]
# Successful run 202: [3, 7, 1, 5, 6, 2, 0, 4]
# Successful run 203: [5, 1, 3, 4, 2, 7, 6, 0]
# Successful run 204: [0, 1, 7, 4, 5, 2, 6, 3]
# Successful run 205: [1, 3, 7, 2, 0, 4, 5, 6]
# Successful run 206: [1, 3, 6, 7, 2, 4, 0, 5]
# Successful run 207: [5, 7, 1, 6, 0, 2, 4, 3]
# Successful run 208: [5, 6, 3, 2, 1, 4, 0, 7]
# Successful run 209: [2, 6, 3, 4, 1, 5, 7, 0]
# Successful run 210: [0, 7, 1, 2, 4, 5, 6, 3]
# Successful run 211: [5, 7, 4, 2, 1, 0, 6, 3]
# Successful run 212: [0, 7, 5, 3, 6, 1, 4, 2]
# Successful run 213: [4, 1, 2, 7, 6, 0, 3, 5]
# Successful run 214: [4, 1, 3, 0, 7, 6, 2, 5]
# Successful run 215: [4, 7, 5, 2, 3, 1, 0, 6]
# Successful run 216: [3, 4, 6, 5, 2, 1, 7, 0]
# Successful run 217: [3, 4, 2, 1, 5, 0, 7, 6]
# Successful run 218: [0, 5, 3, 4, 2, 7, 6, 1]
# Successful run 219: [0, 3, 4, 1, 7, 6, 5, 2]
# Successful run 220: [6, 3, 0, 5, 7, 1, 2, 4]
# Successful run 221: [1, 2, 6, 5, 4, 3, 0, 7]
# Successful run 222: [0, 3, 4, 5, 7, 6, 1, 2]
# Successful run 223: [1, 4, 5, 7, 6, 2, 0, 3]
# Successful run 224: [3, 5, 6, 1, 2, 0, 4, 7]
# Successful run 225: [4, 6, 7, 0, 1, 5, 3, 2]
# Successful run 226: [4, 6, 1, 3, 7, 0, 5, 2]
# Successful run 227: [1, 4, 2, 3, 7, 5, 0, 6]
# Successful run 228: [2, 0, 4, 5, 6, 7, 1, 3]
# Successful run 229: [1, 2, 3, 4, 0, 5, 6, 7]
# Successful run 230: [1, 7, 3, 0, 5, 4, 2, 6]
# Successful run 231: [7, 5, 0, 4, 6, 1, 2, 3]
# Successful run 232: [2, 0, 4, 7, 5, 6, 3, 1]
# Successful run 233: [4, 3, 1, 6, 5, 0, 7, 2]
# Successful run 234: [3, 7, 6, 5, 1, 4, 0, 2]
# Successful run 235: [4, 0, 5, 2, 7, 6, 3, 1]
# Successful run 236: [1, 2, 6, 5, 7, 4, 3, 0]
# Successful run 237: [5, 6, 2, 0, 1, 3, 7, 4]
# Successful run 238: [4, 7, 5, 3, 2, 1, 6, 0]
# Successful run 239: [4, 6, 5, 2, 0, 3, 7, 1]
# Successful run 240: [0, 3, 5, 2, 7, 1, 4, 6]
# Successful run 241: [6, 3, 2, 0, 4, 1, 5, 7]
# Successful run 242: [0, 1, 5, 2, 4, 3, 6, 7]
# Successful run 243: [7, 4, 5, 6, 1, 3, 0, 2]
# Successful run 244: [4, 2, 5, 3, 6, 0, 1, 7]
# Successful run 245: [3, 2, 7, 4, 6, 0, 5, 1]
# Successful run 246: [2, 4, 7, 6, 3, 5, 0, 1]
# Successful run 247: [6, 5, 2, 4, 0, 7, 3, 1]
# Successful run 248: [6, 1, 7, 0, 3, 4, 5, 2]
# Successful run 249: [7, 1, 4, 0, 6, 5, 3, 2]
# Successful run 250: [7, 3, 4, 5, 1, 2, 0, 6]
# Successful run 251: [6, 1, 7, 4, 2, 0, 3, 5]
# Successful run 252: [2, 5, 1, 0, 6, 7, 3, 4]
# Successful run 253: [6, 4, 3, 0, 2, 5, 1, 7]
# Successful run 254: [4, 6, 3, 2, 0, 7, 1, 5]
# Successful run 255: [7, 5, 4, 1, 2, 0, 3, 6]
# Successful run 256: [5, 6, 1, 4, 3, 0, 2, 7]
# Successful run 257: [3, 6, 0, 4, 5, 7, 1, 2]
# Successful run 258: [4, 7, 5, 6, 2, 0, 3, 1]
# Successful run 259: [7, 0, 1, 6, 4, 2, 5, 3]
# Successful run 260: [1, 4, 3, 2, 7, 0, 5, 6]
# Successful run 261: [3, 0, 2, 1, 4, 5, 6, 7]
# Successful run 262: [3, 2, 1, 7, 6, 4, 0, 5]
# Successful run 263: [4, 6, 0, 3, 1, 5, 2, 7]
# Successful run 264: [3, 6, 2, 1, 7, 5, 0, 4]
# Successful run 265: [3, 5, 2, 1, 6, 7, 0, 4]
# Successful run 266: [3, 0, 6, 2, 4, 7, 5, 1]
# Successful run 267: [6, 0, 4, 2, 3, 5, 1, 7]
# Successful run 268: [6, 2, 1, 7, 4, 0, 5, 3]
# Successful run 269: [3, 1, 2, 0, 4, 7, 6, 5]
# Successful run 270: [5, 1, 4, 0, 2, 6, 3, 7]
# Successful run 271: [3, 4, 5, 2, 0, 7, 6, 1]
# Successful run 272: [4, 2, 1, 3, 7, 0, 6, 5]
# Successful run 273: [4, 2, 1, 3, 0, 7, 6, 5]
# Successful run 274: [0, 1, 2, 6, 7, 4, 5, 3]
# Successful run 275: [0, 7, 4, 2, 5, 6, 3, 1]
# Successful run 276: [5, 2, 3, 4, 7, 6, 0, 1]
# Successful run 277: [4, 6, 5, 2, 3, 1, 0, 7]
# Successful run 278: [3, 5, 1, 0, 2, 6, 4, 7]
# Successful run 279: [0, 2, 7, 6, 5, 1, 4, 3]
# Successful run 280: [6, 5, 4, 3, 0, 1, 7, 2]
# Successful run 281: [7, 4, 1, 5, 0, 2, 6, 3]
# Successful run 282: [6, 1, 0, 5, 2, 3, 4, 7]
# Successful run 283: [0, 7, 6, 3, 5, 1, 4, 2]
# Successful run 284: [3, 5, 0, 7, 6, 4, 1, 2]
# Successful run 285: [2, 1, 0, 3, 4, 5, 6, 7]
# Successful run 286: [5, 1, 7, 3, 0, 2, 6, 4]
# Successful run 287: [7, 6, 0, 4, 2, 3, 1, 5]
# Successful run 288: [1, 7, 0, 3, 2, 6, 4, 5]
# Successful run 289: [1, 4, 6, 7, 2, 5, 0, 3]
# Successful run 290: [5, 2, 7, 6, 3, 4, 1, 0]
# Successful run 291: [1, 4, 2, 3, 6, 7, 5, 0]
# Successful run 292: [5, 2, 0, 3, 6, 4, 7, 1]
# Successful run 293: [7, 0, 3, 6, 5, 1, 2, 4]
# Successful run 294: [1, 6, 3, 4, 2, 5, 7, 0]
# Successful run 295: [6, 7, 2, 4, 3, 1, 5, 0]
# Successful run 296: [0, 3, 4, 2, 6, 1, 7, 5]
# Successful run 297: [3, 1, 5, 7, 0, 6, 2, 4]
# Successful run 298: [2, 0, 7, 4, 1, 5, 6, 3]
# Successful run 299: [7, 2, 6, 3, 4, 0, 1, 5]
# Successful run 300: [0, 4, 1, 7, 6, 3, 2, 5]
# Successful run 301: [5, 4, 2, 6, 3, 1, 0, 7]
# Successful run 302: [1, 6, 5, 4, 2, 3, 0, 7]
# Successful run 303: [1, 7, 4, 2, 5, 0, 6, 3]
# Successful run 304: [6, 1, 4, 5, 3, 2, 7, 0]
# Successful run 305: [0, 5, 7, 2, 1, 3, 4, 6]
# Successful run 306: [1, 5, 7, 3, 2, 6, 0, 4]
# Successful run 307: [4, 1, 2, 7, 6, 5, 0, 3]
# Successful run 308: [5, 3, 2, 6, 4, 1, 7, 0]
# Successful run 309: [4, 5, 3, 6, 1, 7, 0, 2]
# Successful run 310: [7, 6, 1, 4, 2, 0, 5, 3]
# Successful run 311: [6, 7, 1, 0, 4, 2, 5, 3]
# Successful run 312: [5, 4, 6, 7, 1, 0, 2, 3]
# Successful run 313: [2, 6, 0, 5, 7, 4, 3, 1]
# Successful run 314: [7, 4, 0, 1, 2, 3, 6, 5]
# Successful run 315: [7, 4, 6, 0, 5, 2, 1, 3]
# Successful run 316: [3, 0, 6, 1, 2, 4, 7, 5]
# Successful run 317: [3, 6, 5, 7, 4, 1, 0, 2]
# Successful run 318: [0, 2, 4, 7, 5, 1, 3, 6]
# Successful run 319: [0, 7, 2, 1, 3, 6, 5, 4]
# Successful run 320: [4, 0, 3, 5, 1, 7, 2, 6]
# Successful run 321: [7, 6, 4, 3, 1, 5, 2, 0]
# Successful run 322: [3, 2, 4, 0, 1, 6, 7, 5]
# Successful run 323: [0, 5, 2, 1, 7, 3, 4, 6]
# Successful run 324: [4, 5, 1, 2, 3, 6, 0, 7]
# Successful run 325: [1, 7, 3, 6, 4, 2, 5, 0]
# Successful run 326: [0, 6, 1, 3, 5, 4, 2, 7]
# Successful run 327: [2, 5, 7, 6, 3, 1, 0, 4]
# Successful run 328: [7, 6, 4, 5, 3, 1, 2, 0]
# Successful run 329: [4, 3, 1, 7, 5, 6, 0, 2]
# Successful run 330: [0, 4, 3, 2, 1, 6, 5, 7]
# Successful run 331: [0, 4, 2, 7, 6, 5, 1, 3]
# Successful run 332: [3, 2, 5, 7, 0, 1, 4, 6]
# Successful run 333: [1, 4, 0, 7, 6, 2, 3, 5]
# Successful run 334: [5, 6, 1, 4, 7, 2, 0, 3]
# Successful run 335: [0, 6, 1, 4, 2, 5, 7, 3]
# Successful run 336: [6, 5, 7, 0, 3, 4, 2, 1]
# Successful run 337: [2, 6, 5, 7, 3, 0, 1, 4]
# Successful run 338: [2, 5, 0, 6, 1, 4, 3, 7]
# Successful run 339: [3, 7, 6, 4, 2, 5, 0, 1]
# Successful run 340: [2, 1, 6, 5, 0, 3, 4, 7]
# Successful run 341: [6, 4, 0, 1, 3, 2, 5, 7]
# Successful run 342: [0, 1, 7, 3, 2, 5, 4, 6]
# Successful run 343: [2, 3, 6, 7, 4, 5, 1, 0]
# Successful run 344: [1, 6, 0, 5, 7, 3, 4, 2]
# Successful run 345: [4, 7, 1, 6, 3, 2, 0, 5]
# Successful run 346: [5, 0, 7, 4, 3, 1, 2, 6]
# Successful run 347: [7, 1, 4, 2, 0, 6, 5, 3]
# Successful run 348: [7, 5, 4, 3, 6, 1, 0, 2]
# Successful run 349: [1, 3, 7, 5, 6, 4, 0, 2]
# Successful run 350: [2, 5, 1, 3, 6, 0, 4, 7]
# Successful run 351: [6, 1, 5, 7, 0, 4, 3, 2]
# Successful run 352: [5, 3, 1, 4, 0, 2, 6, 7]
# Successful run 353: [6, 0, 4, 5, 1, 3, 7, 2]
# Successful run 354: [2, 1, 5, 3, 4, 7, 0, 6]
# Successful run 355: [1, 2, 6, 3, 5, 7, 4, 0]
# Successful run 356: [3, 5, 4, 0, 2, 7, 1, 6]
# Successful run 357: [7, 4, 0, 6, 5, 1, 2, 3]
# Successful run 358: [5, 6, 0, 3, 1, 2, 7, 4]
# Successful run 359: [2, 1, 3, 5, 7, 4, 0, 6]
# Successful run 360: [6, 2, 5, 1, 3, 4, 7, 0]
# Successful run 361: [3, 5, 2, 6, 0, 1, 4, 7]
# Successful run 362: [1, 6, 0, 3, 4, 5, 7, 2]
# Successful run 363: [3, 7, 4, 1, 2, 6, 0, 5]
# Successful run 364: [1, 0, 6, 7, 3, 2, 4, 5]
# Successful run 365: [2, 6, 4, 3, 1, 0, 5, 7]
# Successful run 366: [5, 1, 4, 7, 0, 6, 2, 3]
# Successful run 367: [3, 5, 0, 2, 4, 1, 6, 7]
# Successful run 368: [1, 5, 6, 3, 2, 4, 0, 7]
# Successful run 369: [4, 0, 6, 5, 2, 3, 7, 1]
# Successful run 370: [6, 5, 0, 1, 2, 7, 4, 3]
# Successful run 371: [2, 1, 6, 0, 4, 5, 7, 3]
# Successful run 372: [7, 0, 4, 5, 3, 1, 2, 6]
# Successful run 373: [6, 2, 5, 0, 3, 7, 1, 4]
# Successful run 374: [2, 6, 3, 7, 4, 5, 0, 1]
# Successful run 375: [4, 2, 0, 3, 6, 1, 5, 7]
# Successful run 376: [3, 0, 2, 6, 1, 4, 7, 5]
# Successful run 377: [1, 6, 5, 2, 7, 4, 3, 0]
# Successful run 378: [6, 1, 2, 5, 0, 3, 4, 7]
# Successful run 379: [2, 4, 0, 7, 1, 5, 6, 3]
# Successful run 380: [2, 5, 3, 7, 6, 1, 4, 0]
# Successful run 381: [1, 6, 7, 0, 2, 4, 3, 5]
# Successful run 382: [3, 7, 0, 2, 6, 1, 5, 4]
# Successful run 383: [6, 5, 0, 2, 1, 3, 7, 4]
# Successful run 384: [1, 0, 2, 6, 5, 3, 4, 7]
# Successful run 385: [4, 2, 7, 0, 5, 3, 1, 6]
# Successful run 386: [6, 2, 4, 0, 3, 7, 1, 5]
# Successful run 387: [7, 5, 2, 4, 3, 0, 6, 1]
# Successful run 388: [0, 6, 1, 5, 2, 7, 3, 4]
# Successful run 389: [4, 6, 5, 0, 2, 7, 3, 1]
# Successful run 390: [6, 3, 1, 7, 2, 5, 0, 4]
# Successful run 391: [5, 6, 2, 7, 1, 0, 4, 3]
# Successful run 392: [1, 0, 6, 2, 7, 5, 3, 4]
# Successful run 393: [1, 7, 0, 5, 6, 2, 3, 4]
# Successful run 394: [0, 1, 4, 7, 3, 2, 6, 5]
# Successful run 395: [3, 2, 6, 7, 0, 4, 5, 1]
# Successful run 396: [7, 5, 3, 1, 2, 0, 4, 6]
# Successful run 397: [6, 1, 7, 4, 0, 3, 5, 2]
# Successful run 398: [1, 6, 5, 2, 7, 3, 4, 0]
# Successful run 399: [1, 5, 6, 3, 7, 2, 0, 4]
# Successful run 400: [2, 4, 7, 6, 3, 0, 5, 1]
# Successful run 401: [7, 3, 5, 1, 2, 0, 4, 6]
# Successful run 402: [0, 3, 6, 5, 7, 1, 4, 2]
# Successful run 403: [3, 6, 5, 2, 1, 7, 0, 4]
# Successful run 404: [5, 7, 1, 6, 2, 4, 0, 3]
# Successful run 405: [4, 3, 2, 0, 7, 6, 5, 1]
# Successful run 406: [0, 3, 2, 5, 1, 7, 4, 6]
# Successful run 407: [5, 2, 4, 6, 0, 3, 7, 1]
# Successful run 408: [5, 2, 1, 6, 0, 4, 7, 3]
# Successful run 409: [2, 3, 7, 5, 4, 0, 6, 1]
# Successful run 410: [0, 6, 4, 1, 5, 7, 3, 2]
# Successful run 411: [7, 1, 4, 5, 6, 0, 3, 2]
# Successful run 412: [6, 5, 1, 3, 7, 0, 4, 2]
# Successful run 413: [3, 4, 5, 2, 1, 0, 7, 6]
# Successful run 414: [3, 7, 1, 2, 5, 4, 6, 0]
# Successful run 415: [5, 6, 0, 2, 4, 7, 3, 1]
# Successful run 416: [3, 1, 5, 0, 7, 2, 6, 4]
# Successful run 417: [1, 7, 3, 6, 4, 0, 5, 2]
# Successful run 418: [4, 6, 3, 5, 2, 7, 1, 0]
# Successful run 419: [7, 5, 2, 4, 6, 1, 0, 3]
# Successful run 420: [4, 0, 2, 7, 3, 1, 5, 6]
# Successful run 421: [0, 6, 7, 2, 1, 5, 3, 4]
# Successful run 422: [5, 0, 7, 1, 2, 6, 4, 3]
# Successful run 423: [7, 3, 6, 5, 1, 2, 4, 0]
# Successful run 424: [7, 5, 2, 0, 3, 1, 6, 4]
# Successful run 425: [7, 2, 3, 4, 1, 5, 6, 0]
# Successful run 426: [1, 2, 6, 3, 7, 5, 0, 4]
# Successful run 427: [6, 0, 7, 5, 3, 2, 1, 4]
# Successful run 428: [7, 6, 2, 3, 4, 0, 1, 5]
# Successful run 429: [2, 4, 5, 0, 1, 7, 3, 6]
# Successful run 430: [0, 7, 2, 3, 4, 6, 1, 5]
# Successful run 431: [5, 2, 6, 3, 7, 4, 1, 0]
# Successful run 432: [3, 2, 7, 0, 6, 5, 1, 4]
# Successful run 433: [2, 0, 4, 3, 1, 5, 7, 6]
# Successful run 434: [4, 5, 0, 7, 2, 1, 6, 3]
# Successful run 435: [1, 4, 3, 6, 7, 5, 2, 0]
# Successful run 436: [6, 0, 7, 3, 1, 4, 2, 5]
# Successful run 437: [0, 1, 3, 4, 2, 7, 5, 6]
# Successful run 438: [3, 5, 6, 0, 2, 7, 1, 4]
# Successful run 439: [5, 1, 2, 3, 6, 4, 7, 0]
# Successful run 440: [2, 4, 7, 6, 1, 0, 3, 5]
# Successful run 441: [4, 5, 6, 1, 0, 3, 7, 2]
# Successful run 442: [3, 0, 7, 1, 2, 5, 6, 4]
# Successful run 443: [3, 1, 5, 0, 6, 2, 4, 7]
# Successful run 444: [6, 1, 5, 7, 3, 4, 0, 2]
# Successful run 445: [6, 3, 1, 7, 2, 5, 0, 4]
# Successful run 446: [7, 5, 0, 4, 3, 2, 6, 1]
# Successful run 447: [3, 4, 5, 2, 7, 0, 1, 6]
# Successful run 448: [1, 5, 4, 6, 3, 7, 2, 0]
# Successful run 449: [3, 2, 0, 4, 1, 6, 5, 7]
# Successful run 450: [3, 5, 7, 0, 1, 6, 4, 2]
# Successful run 451: [0, 1, 5, 2, 6, 3, 7, 4]
# Successful run 452: [0, 7, 5, 4, 6, 1, 2, 3]
# Successful run 453: [3, 1, 4, 0, 7, 6, 2, 5]
# Successful run 454: [7, 3, 5, 1, 6, 2, 4, 0]
# Successful run 455: [5, 0, 3, 6, 7, 4, 2, 1]
# Successful run 456: [2, 1, 7, 4, 0, 6, 5, 3]
# Successful run 457: [2, 7, 3, 1, 0, 4, 6, 5]
# Successful run 458: [5, 0, 4, 6, 1, 3, 7, 2]
# Successful run 459: [3, 0, 7, 5, 1, 6, 2, 4]
# Successful run 460: [3, 1, 5, 0, 7, 4, 6, 2]
# Successful run 461: [1, 6, 5, 3, 4, 0, 2, 7]
# Successful run 462: [6, 5, 2, 3, 1, 7, 4, 0]
# Successful run 463: [4, 1, 7, 0, 3, 5, 2, 6]
# Successful run 464: [7, 3, 5, 0, 4, 1, 2, 6]
# Successful run 465: [2, 7, 6, 1, 5, 0, 4, 3]
# Successful run 466: [2, 3, 6, 4, 5, 7, 1, 0]
# Successful run 467: [1, 7, 4, 3, 6, 5, 2, 0]
# Successful run 468: [5, 0, 4, 7, 1, 6, 3, 2]
# Successful run 469: [0, 6, 3, 1, 2, 4, 7, 5]
# Successful run 470: [0, 4, 5, 2, 3, 1, 6, 7]
# Successful run 471: [5, 2, 0, 1, 3, 7, 6, 4]
# Successful run 472: [7, 5, 2, 3, 4, 6, 1, 0]
# Successful run 473: [2, 6, 4, 7, 5, 1, 0, 3]
# Successful run 474: [6, 2, 1, 3, 5, 0, 4, 7]
# Successful run 475: [0, 5, 3, 4, 7, 2, 6, 1]
# Successful run 476: [0, 2, 5, 3, 6, 1, 7, 4]
# Successful run 477: [3, 2, 4, 6, 1, 5, 0, 7]
# Successful run 478: [2, 6, 4, 7, 0, 3, 5, 1]
# Successful run 479: [1, 0, 4, 7, 2, 3, 6, 5]
# Successful run 480: [2, 3, 4, 7, 6, 1, 0, 5]
# Successful run 481: [5, 0, 7, 4, 2, 1, 3, 6]
# Successful run 482: [6, 4, 1, 3, 2, 7, 0, 5]
# Successful run 483: [2, 5, 6, 1, 0, 4, 7, 3]
# Successful run 484: [2, 3, 0, 4, 1, 6, 5, 7]
# Successful run 485: [2, 0, 7, 1, 5, 6, 4, 3]
# Successful run 486: [3, 7, 2, 0, 6, 4, 5, 1]
# Successful run 487: [5, 1, 7, 3, 6, 2, 4, 0]
# Successful run 488: [5, 0, 6, 1, 3, 2, 7, 4]
# Successful run 489: [6, 7, 3, 1, 0, 2, 4, 5]
# Successful run 490: [7, 5, 3, 4, 6, 1, 0, 2]
# Successful run 491: [4, 2, 3, 5, 1, 6, 7, 0]
# Successful run 492: [3, 0, 5, 6, 4, 7, 2, 1]
# Successful run 493: [0, 5, 1, 3, 6, 2, 4, 7]
# Successful run 494: [0, 5, 6, 4, 2, 7, 1, 3]
# Successful run 495: [3, 1, 4, 7, 6, 2, 0, 5]
# Successful run 496: [6, 1, 0, 5, 2, 7, 4, 3]
# Successful run 497: [6, 4, 2, 7, 0, 5, 1, 3]
# Successful run 498: [7, 2, 0, 6, 1, 3, 5, 4]
# Successful run 499: [3, 7, 6, 1, 4, 0, 5, 2]
# Successful run 500: [0, 5, 7, 4, 3, 1, 6, 2]
# Successful run 501: [1, 7, 5, 0, 4, 6, 2, 3]
# Successful run 502: [6, 4, 0, 7, 1, 3, 2, 5]
# Successful run 503: [2, 5, 4, 0, 7, 1, 6, 3]
# Successful run 504: [4, 5, 2, 7, 0, 1, 6, 3]
# Successful run 505: [4, 6, 5, 7, 1, 3, 0, 2]
# Successful run 506: [6, 0, 3, 2, 1, 5, 7, 4]
# Successful run 507: [4, 2, 1, 3, 5, 0, 7, 6]
# Successful run 508: [2, 4, 5, 6, 0, 7, 1, 3]
# Successful run 509: [0, 7, 3, 2, 5, 6, 4, 1]
# Successful run 510: [4, 7, 3, 2, 0, 5, 6, 1]
# Successful run 511: [1, 5, 0, 6, 2, 3, 4, 7]
# Successful run 512: [6, 1, 7, 2, 3, 5, 0, 4]
# Successful run 513: [3, 1, 2, 4, 6, 5, 7, 0]
# Successful run 514: [4, 6, 2, 7, 3, 0, 5, 1]
# Successful run 515: [0, 6, 2, 1, 5, 4, 7, 3]
# Successful run 516: [5, 3, 6, 7, 2, 4, 0, 1]
# Successful run 517: [7, 5, 1, 6, 0, 2, 3, 4]
# Successful run 518: [3, 2, 7, 0, 6, 5, 1, 4]
# Successful run 519: [1, 7, 4, 3, 5, 2, 0, 6]
# Successful run 520: [0, 2, 1, 6, 4, 5, 7, 3]
# Successful run 521: [4, 5, 1, 0, 7, 2, 3, 6]
# Successful run 522: [3, 6, 0, 7, 4, 5, 2, 1]
# Successful run 523: [1, 7, 5, 6, 4, 3, 2, 0]
# Successful run 524: [5, 3, 1, 4, 6, 2, 0, 7]
# Successful run 525: [5, 0, 4, 7, 6, 2, 3, 1]
# Successful run 526: [7, 6, 4, 3, 0, 2, 5, 1]
# Successful run 527: [5, 3, 0, 1, 6, 4, 7, 2]
# Successful run 528: [2, 3, 7, 1, 6, 0, 4, 5]
# Successful run 529: [2, 7, 4, 6, 0, 3, 5, 1]
# Successful run 530: [5, 6, 2, 4, 1, 7, 0, 3]
# Successful run 531: [1, 6, 4, 0, 2, 5, 7, 3]
# Successful run 532: [0, 7, 3, 4, 2, 6, 5, 1]
# Successful run 533: [4, 3, 6, 5, 0, 1, 7, 2]
# Successful run 534: [3, 6, 7, 5, 2, 0, 4, 1]
# Successful run 535: [4, 2, 1, 6, 3, 7, 5, 0]
# Successful run 536: [1, 0, 5, 7, 6, 4, 3, 2]
# Successful run 537: [2, 6, 1, 3, 5, 0, 7, 4]
# Successful run 538: [3, 7, 5, 2, 4, 6, 0, 1]
# Successful run 539: [0, 2, 4, 7, 6, 5, 1, 3]
# Successful run 540: [3, 6, 1, 7, 5, 2, 4, 0]
# Successful run 541: [5, 6, 7, 1, 2, 0, 4, 3]
# Successful run 542: [1, 5, 4, 7, 0, 3, 6, 2]
# Successful run 543: [2, 3, 7, 1, 0, 6, 5, 4]
# Successful run 544: [1, 3, 7, 0, 4, 5, 2, 6]
# Successful run 545: [1, 3, 4, 0, 5, 6, 2, 7]
# Successful run 546: [3, 5, 0, 6, 7, 1, 2, 4]
# Successful run 547: [3, 5, 2, 6, 0, 4, 1, 7]
# Successful run 548: [4, 7, 3, 1, 2, 6, 5, 0]
# Successful run 549: [5, 0, 6, 4, 2, 3, 1, 7]
# Successful run 550: [3, 7, 4, 0, 6, 2, 1, 5]
# Successful run 551: [4, 2, 1, 3, 6, 5, 7, 0]
# Successful run 552: [4, 7, 0, 2, 6, 1, 5, 3]
# Successful run 553: [4, 0, 6, 2, 3, 1, 5, 7]
# Successful run 554: [7, 2, 1, 6, 4, 5, 3, 0]
# Successful run 555: [5, 4, 2, 7, 3, 0, 6, 1]
# Successful run 556: [7, 2, 5, 0, 3, 4, 1, 6]
# Successful run 557: [5, 1, 7, 3, 0, 6, 4, 2]
# Successful run 558: [7, 2, 4, 1, 5, 6, 0, 3]
# Successful run 559: [4, 3, 7, 1, 6, 2, 5, 0]
# Successful run 560: [1, 7, 6, 0, 5, 3, 4, 2]
# Successful run 561: [7, 4, 1, 3, 0, 2, 6, 5]
# Successful run 562: [3, 7, 6, 4, 1, 5, 2, 0]
# Successful run 563: [7, 4, 1, 2, 6, 5, 3, 0]
# Successful run 564: [4, 5, 3, 1, 2, 0, 6, 7]
# Successful run 565: [1, 2, 3, 4, 0, 5, 6, 7]
# Successful run 566: [4, 0, 2, 7, 5, 3, 6, 1]
# Successful run 567: [4, 7, 6, 3, 1, 2, 0, 5]
# Successful run 568: [5, 0, 3, 1, 6, 4, 2, 7]
# Successful run 569: [7, 6, 1, 4, 5, 0, 3, 2]
# Successful run 570: [1, 5, 0, 4, 2, 7, 3, 6]
# Successful run 571: [3, 1, 4, 2, 0, 5, 7, 6]
# Successful run 572: [5, 2, 1, 6, 0, 4, 7, 3]
# Successful run 573: [0, 5, 7, 2, 1, 3, 4, 6]
# Successful run 574: [0, 3, 1, 5, 4, 7, 6, 2]
# Successful run 575: [6, 1, 7, 0, 4, 2, 5, 3]
# Successful run 576: [5, 6, 3, 7, 4, 1, 0, 2]
# Successful run 577: [6, 4, 7, 5, 1, 0, 3, 2]
# Successful run 578: [3, 0, 2, 1, 4, 5, 6, 7]
# Successful run 579: [0, 3, 7, 4, 2, 1, 5, 6]
# Successful run 580: [4, 6, 5, 1, 2, 7, 0, 3]
# Successful run 581: [5, 2, 0, 3, 7, 4, 1, 6]
# Successful run 582: [4, 2, 7, 1, 5, 0, 6, 3]
# Successful run 583: [2, 5, 3, 0, 7, 4, 1, 6]
# Successful run 584: [5, 3, 2, 6, 4, 1, 0, 7]
# Successful run 585: [3, 7, 4, 6, 2, 0, 5, 1]
# Successful run 586: [3, 2, 5, 6, 4, 1, 7, 0]
# Successful run 587: [1, 0, 5, 7, 2, 3, 6, 4]
# Successful run 588: [5, 2, 0, 3, 6, 1, 7, 4]
# Successful run 589: [2, 0, 4, 7, 1, 6, 5, 3]
# Successful run 590: [6, 5, 7, 0, 3, 1, 2, 4]
# Successful run 591: [6, 1, 7, 4, 2, 3, 5, 0]
# Successful run 592: [4, 2, 1, 3, 5, 7, 0, 6]
# Successful run 593: [2, 1, 4, 6, 5, 3, 0, 7]
# Successful run 594: [0, 2, 3, 1, 7, 5, 6, 4]
# Successful run 595: [3, 7, 6, 0, 4, 5, 2, 1]
# Successful run 596: [0, 1, 4, 7, 5, 6, 2, 3]
# Successful run 597: [1, 6, 5, 3, 2, 7, 0, 4]
# Successful run 598: [2, 0, 5, 4, 3, 6, 1, 7]
# Successful run 599: [1, 4, 5, 0, 7, 3, 6, 2]
# Successful run 600: [6, 2, 4, 1, 0, 7, 3, 5]
# Successful run 601: [0, 3, 4, 7, 2, 6, 5, 1]
# Successful run 602: [6, 1, 7, 4, 0, 2, 5, 3]
# Successful run 603: [3, 6, 0, 2, 5, 1, 7, 4]
# Successful run 604: [3, 1, 2, 4, 5, 7, 0, 6]
# Successful run 605: [3, 0, 7, 4, 1, 6, 5, 2]
# Successful run 606: [4, 5, 3, 7, 0, 2, 6, 1]
# Successful run 607: [6, 5, 3, 7, 1, 2, 0, 4]
# Successful run 608: [2, 3, 7, 6, 1, 4, 0, 5]
# Successful run 609: [7, 1, 5, 4, 6, 3, 2, 0]
# Successful run 610: [6, 2, 1, 5, 3, 4, 0, 7]
# Successful run 611: [0, 2, 6, 4, 7, 5, 1, 3]
# Successful run 612: [3, 5, 4, 7, 6, 0, 1, 2]
# Successful run 613: [0, 4, 5, 3, 2, 1, 6, 7]
# Successful run 614: [0, 1, 7, 4, 6, 5, 3, 2]
# Successful run 615: [7, 0, 3, 6, 4, 1, 2, 5]
# Successful run 616: [7, 0, 2, 5, 1, 6, 3, 4]
# Successful run 617: [3, 2, 6, 7, 4, 5, 0, 1]
# Successful run 618: [6, 3, 1, 7, 4, 0, 5, 2]
# Successful run 619: [7, 0, 1, 3, 5, 4, 2, 6]
# Successful run 620: [1, 3, 2, 4, 0, 6, 5, 7]
# Successful run 621: [5, 2, 6, 1, 4, 7, 0, 3]
# Successful run 622: [1, 0, 4, 5, 6, 7, 2, 3]
# Successful run 623: [6, 3, 0, 5, 2, 1, 4, 7]
# Successful run 624: [4, 5, 1, 3, 6, 7, 0, 2]
# Successful run 625: [0, 3, 4, 7, 5, 1, 2, 6]
# Successful run 626: [1, 4, 6, 0, 5, 3, 7, 2]
# Successful run 627: [5, 6, 3, 7, 2, 1, 0, 4]
# Successful run 628: [2, 4, 6, 3, 7, 5, 0, 1]
# Successful run 629: [4, 3, 6, 2, 5, 0, 1, 7]
# Successful run 630: [3, 4, 6, 5, 7, 0, 2, 1]
# Successful run 631: [6, 2, 4, 3, 5, 0, 7, 1]
# Successful run 632: [3, 6, 7, 5, 2, 1, 0, 4]
# Successful run 633: [4, 0, 5, 3, 7, 2, 1, 6]
# Successful run 634: [3, 6, 4, 2, 5, 0, 1, 7]
# Successful run 635: [4, 3, 2, 5, 0, 1, 6, 7]
# Successful run 636: [3, 6, 5, 7, 2, 1, 0, 4]
# Successful run 637: [3, 1, 7, 0, 2, 6, 5, 4]
# Successful run 638: [2, 6, 1, 0, 5, 7, 4, 3]
# Successful run 639: [4, 1, 0, 7, 3, 2, 5, 6]
# Successful run 640: [6, 0, 2, 5, 1, 3, 4, 7]
# Successful run 641: [6, 4, 1, 3, 0, 7, 5, 2]
# Successful run 642: [2, 7, 4, 5, 6, 1, 0, 3]
# Successful run 643: [6, 0, 7, 4, 5, 3, 1, 2]
# Successful run 644: [4, 3, 1, 6, 2, 5, 0, 7]
# Successful run 645: [0, 1, 5, 6, 4, 7, 2, 3]
# Successful run 646: [1, 3, 0, 5, 7, 2, 4, 6]
# Successful run 647: [2, 3, 7, 1, 6, 0, 4, 5]
# Successful run 648: [3, 2, 1, 0, 6, 7, 5, 4]
# Successful run 649: [6, 5, 3, 7, 4, 1, 2, 0]
# Successful run 650: [0, 7, 6, 4, 3, 5, 1, 2]
# Successful run 651: [7, 5, 4, 2, 0, 1, 6, 3]
# Successful run 652: [0, 1, 5, 3, 4, 7, 6, 2]
# Successful run 653: [6, 1, 7, 0, 2, 3, 5, 4]
# Successful run 654: [1, 6, 7, 0, 3, 5, 4, 2]
# Successful run 655: [6, 0, 5, 2, 4, 7, 1, 3]
# Successful run 656: [4, 6, 0, 3, 2, 5, 7, 1]
# Successful run 657: [2, 0, 4, 6, 1, 7, 3, 5]
# Successful run 658: [7, 5, 6, 3, 1, 0, 4, 2]
# Successful run 659: [3, 6, 2, 5, 4, 7, 1, 0]
# Successful run 660: [3, 1, 6, 0, 5, 2, 4, 7]
# Successful run 661: [7, 2, 3, 5, 1, 4, 6, 0]
# Successful run 662: [4, 2, 6, 7, 5, 3, 1, 0]
# Successful run 663: [4, 0, 5, 6, 7, 1, 3, 2]
# Successful run 664: [5, 7, 6, 2, 4, 0, 3, 1]
# Successful run 665: [0, 6, 7, 4, 1, 3, 5, 2]
# Successful run 666: [2, 1, 3, 6, 7, 0, 4, 5]
# Successful run 667: [6, 0, 7, 3, 2, 5, 4, 1]
# Successful run 668: [6, 3, 7, 4, 1, 0, 5, 2]
# Successful run 669: [3, 1, 6, 0, 4, 5, 7, 2]
# Successful run 670: [6, 7, 3, 1, 5, 2, 0, 4]
# Successful run 671: [0, 2, 4, 5, 6, 7, 3, 1]
# Successful run 672: [7, 6, 2, 4, 0, 1, 5, 3]
# Successful run 673: [7, 6, 3, 1, 5, 4, 0, 2]
# Successful run 674: [5, 7, 3, 0, 4, 6, 2, 1]
# Successful run 675: [7, 5, 4, 1, 6, 0, 2, 3]
# Successful run 676: [1, 3, 7, 6, 2, 4, 5, 0]
# Successful run 677: [6, 5, 2, 1, 4, 7, 3, 0]
# Successful run 678: [2, 1, 5, 4, 7, 3, 6, 0]
# Successful run 679: [0, 3, 7, 6, 2, 1, 4, 5]
# Successful run 680: [7, 0, 4, 5, 3, 2, 1, 6]
# Successful run 681: [0, 7, 4, 1, 5, 3, 6, 2]
# Successful run 682: [6, 4, 0, 2, 3, 1, 7, 5]
# Successful run 683: [3, 1, 4, 7, 6, 0, 2, 5]
# Successful run 684: [0, 3, 2, 1, 6, 4, 7, 5]
# Successful run 685: [4, 2, 6, 0, 1, 7, 3, 5]
# Successful run 686: [3, 6, 2, 5, 0, 7, 1, 4]
# Successful run 687: [0, 3, 5, 7, 2, 1, 4, 6]
# Successful run 688: [3, 5, 7, 1, 6, 0, 2, 4]
# Successful run 689: [5, 6, 3, 2, 0, 1, 7, 4]
# Successful run 690: [1, 3, 2, 7, 4, 6, 0, 5]
# Successful run 691: [0, 7, 5, 6, 1, 4, 2, 3]
# Successful run 692: [4, 7, 3, 1, 5, 2, 6, 0]
# Successful run 693: [4, 6, 2, 3, 0, 1, 5, 7]
# Successful run 694: [4, 0, 6, 1, 3, 2, 5, 7]
# Successful run 695: [6, 7, 5, 3, 0, 2, 4, 1]
# Successful run 696: [0, 7, 3, 1, 5, 2, 4, 6]
# Successful run 697: [3, 6, 5, 0, 7, 4, 2, 1]
# Successful run 698: [0, 7, 1, 5, 2, 3, 6, 4]
# Successful run 699: [3, 4, 2, 0, 7, 6, 5, 1]
# Successful run 700: [5, 0, 4, 1, 3, 2, 7, 6]
# Successful run 701: [3, 0, 5, 1, 6, 7, 2, 4]
# Successful run 702: [5, 2, 4, 7, 6, 3, 0, 1]
# Successful run 703: [7, 6, 5, 3, 1, 0, 4, 2]
# Successful run 704: [0, 3, 5, 1, 2, 4, 7, 6]
# Successful run 705: [6, 4, 3, 1, 7, 5, 2, 0]
# Successful run 706: [7, 5, 1, 2, 6, 0, 4, 3]
# Successful run 707: [4, 2, 5, 1, 7, 3, 0, 6]
# Successful run 708: [5, 7, 1, 4, 6, 3, 0, 2]
# Successful run 709: [1, 4, 5, 6, 2, 7, 0, 3]
# Successful run 710: [5, 1, 2, 4, 6, 7, 3, 0]
# Successful run 711: [7, 2, 6, 5, 1, 3, 4, 0]
# Successful run 712: [6, 5, 0, 4, 2, 7, 3, 1]
# Successful run 713: [6, 4, 1, 0, 7, 3, 2, 5]
# Successful run 714: [5, 6, 1, 0, 4, 7, 3, 2]
# Successful run 715: [0, 6, 3, 4, 7, 2, 1, 5]
# Successful run 716: [2, 0, 3, 6, 7, 1, 4, 5]
# Successful run 717: [0, 7, 3, 2, 5, 1, 6, 4]
# Successful run 718: [5, 4, 3, 6, 2, 7, 0, 1]
# Successful run 719: [2, 7, 6, 4, 0, 5, 1, 3]
# Successful run 720: [5, 2, 6, 3, 7, 1, 0, 4]
# Successful run 721: [0, 1, 4, 6, 7, 3, 5, 2]
# Successful run 722: [6, 1, 7, 0, 5, 2, 4, 3]
# Successful run 723: [5, 7, 3, 0, 1, 2, 4, 6]
# Successful run 724: [1, 3, 2, 4, 0, 6, 5, 7]
# Successful run 725: [2, 1, 7, 6, 4, 3, 0, 5]
# Successful run 726: [7, 6, 1, 4, 3, 2, 0, 5]
# Successful run 727: [5, 4, 1, 6, 2, 7, 3, 0]
# Successful run 728: [5, 7, 0, 2, 1, 4, 6, 3]
# Successful run 729: [0, 7, 6, 1, 5, 3, 2, 4]
# Successful run 730: [2, 4, 6, 1, 0, 7, 5, 3]
# Successful run 731: [4, 6, 1, 0, 5, 7, 2, 3]
# Successful run 732: [4, 3, 1, 0, 7, 6, 2, 5]
# Successful run 733: [1, 3, 5, 6, 7, 4, 2, 0]
# Successful run 734: [6, 1, 4, 3, 5, 2, 7, 0]
# Successful run 735: [6, 2, 1, 0, 5, 3, 7, 4]
# Successful run 736: [3, 6, 4, 2, 5, 0, 1, 7]
# Successful run 737: [0, 1, 6, 4, 7, 3, 5, 2]
# Successful run 738: [3, 2, 5, 7, 6, 1, 4, 0]
# Successful run 739: [0, 3, 1, 6, 7, 4, 2, 5]
# Successful run 740: [3, 7, 4, 5, 6, 0, 2, 1]
# Successful run 741: [7, 2, 6, 3, 0, 4, 5, 1]
# Successful run 742: [2, 0, 4, 7, 3, 1, 6, 5]
# Successful run 743: [1, 2, 4, 0, 6, 5, 7, 3]
# Successful run 744: [5, 0, 2, 7, 4, 3, 1, 6]
# Successful run 745: [5, 0, 4, 2, 3, 6, 7, 1]
# Successful run 746: [7, 4, 6, 0, 1, 3, 5, 2]
# Successful run 747: [6, 0, 3, 4, 2, 1, 5, 7]
# Successful run 748: [6, 5, 7, 0, 4, 2, 1, 3]
# Successful run 749: [3, 7, 6, 4, 1, 2, 5, 0]
# Successful run 750: [5, 7, 3, 1, 0, 6, 2, 4]
# Successful run 751: [5, 2, 4, 1, 3, 0, 7, 6]
# Successful run 752: [2, 0, 5, 6, 1, 3, 4, 7]
# Successful run 753: [4, 3, 1, 6, 5, 2, 7, 0]
# Successful run 754: [6, 1, 5, 7, 2, 4, 3, 0]
# Successful run 755: [0, 3, 5, 2, 1, 7, 4, 6]
# Successful run 756: [4, 3, 5, 1, 2, 0, 6, 7]
# Successful run 757: [7, 2, 6, 5, 3, 0, 4, 1]
# Successful run 758: [7, 4, 0, 1, 3, 5, 6, 2]
# Successful run 759: [7, 0, 4, 3, 2, 6, 1, 5]
# Successful run 760: [5, 3, 1, 2, 4, 6, 7, 0]
# Successful run 761: [2, 5, 6, 7, 3, 4, 0, 1]
# Successful run 762: [0, 5, 2, 7, 1, 3, 6, 4]
# Successful run 763: [5, 3, 4, 1, 2, 6, 7, 0]
# Successful run 764: [2, 5, 1, 4, 6, 3, 7, 0]
# Successful run 765: [7, 5, 2, 6, 0, 3, 1, 4]
# Successful run 766: [4, 1, 0, 7, 6, 5, 3, 2]
# Successful run 767: [0, 3, 6, 7, 2, 4, 1, 5]
# Successful run 768: [7, 4, 6, 5, 1, 0, 2, 3]
# Successful run 769: [5, 4, 0, 6, 2, 7, 3, 1]
# Successful run 770: [6, 3, 5, 4, 2, 7, 0, 1]
# Successful run 771: [1, 5, 7, 4, 2, 6, 0, 3]
# Successful run 772: [5, 6, 4, 2, 1, 3, 0, 7]
# Successful run 773: [7, 1, 0, 4, 6, 3, 5, 2]
# Successful run 774: [0, 3, 6, 4, 5, 2, 1, 7]
# Successful run 775: [7, 3, 5, 0, 2, 6, 4, 1]
# Successful run 776: [3, 2, 7, 5, 1, 0, 4, 6]
# Successful run 777: [0, 3, 7, 5, 6, 2, 4, 1]
# Successful run 778: [7, 5, 1, 4, 3, 6, 2, 0]
# Successful run 779: [6, 2, 7, 5, 4, 0, 3, 1]
# Successful run 780: [0, 7, 3, 2, 6, 1, 5, 4]
# Successful run 781: [0, 3, 4, 2, 7, 5, 6, 1]
# Successful run 782: [3, 5, 2, 0, 6, 1, 4, 7]
# Successful run 783: [3, 1, 5, 2, 7, 4, 6, 0]
# Successful run 784: [5, 4, 0, 7, 6, 3, 1, 2]
# Successful run 785: [6, 4, 7, 2, 3, 5, 1, 0]
# Successful run 786: [6, 1, 4, 2, 7, 5, 0, 3]
# Successful run 787: [2, 7, 6, 1, 3, 4, 0, 5]
# Successful run 788: [2, 0, 1, 3, 5, 7, 6, 4]
# Successful run 789: [6, 7, 4, 3, 2, 1, 5, 0]
# Successful run 790: [7, 3, 1, 2, 6, 5, 0, 4]
# Successful run 791: [2, 6, 3, 1, 0, 7, 5, 4]
# Successful run 792: [7, 3, 1, 4, 2, 6, 0, 5]
# Successful run 793: [6, 0, 5, 7, 3, 1, 2, 4]
# Successful run 794: [0, 4, 7, 6, 3, 5, 1, 2]
# Successful run 795: [1, 2, 5, 6, 0, 7, 3, 4]
# Successful run 796: [6, 5, 1, 0, 3, 7, 2, 4]
# Successful run 797: [5, 3, 2, 4, 1, 7, 6, 0]
# Successful run 798: [7, 3, 1, 4, 5, 0, 2, 6]
# Successful run 799: [2, 0, 4, 6, 7, 3, 5, 1]
# Successful run 800: [1, 5, 3, 0, 6, 4, 7, 2]
# Successful run 801: [2, 3, 4, 5, 7, 6, 0, 1]
# Successful run 802: [0, 1, 7, 3, 6, 5, 4, 2]
# Successful run 803: [2, 7, 1, 0, 4, 3, 6, 5]
# Successful run 804: [2, 4, 6, 3, 7, 1, 0, 5]
# Successful run 805: [0, 3, 2, 4, 1, 6, 7, 5]
# Successful run 806: [7, 6, 5, 4, 0, 3, 2, 1]
# Successful run 807: [4, 3, 5, 0, 7, 1, 6, 2]
# Successful run 808: [7, 6, 2, 0, 1, 4, 3, 5]
# Successful run 809: [1, 6, 2, 0, 3, 4, 5, 7]
# Successful run 810: [6, 4, 7, 2, 1, 0, 5, 3]
# Successful run 811: [4, 3, 5, 2, 7, 0, 1, 6]
# Successful run 812: [0, 6, 4, 3, 7, 1, 2, 5]
# Successful run 813: [2, 7, 5, 3, 1, 0, 6, 4]
# Successful run 814: [5, 6, 3, 2, 4, 0, 7, 1]
# Successful run 815: [7, 4, 6, 0, 3, 2, 5, 1]
# Successful run 816: [2, 1, 4, 3, 5, 7, 0, 6]
# Successful run 817: [5, 4, 6, 0, 2, 3, 7, 1]
# Successful run 818: [7, 1, 3, 5, 0, 4, 6, 2]
# Successful run 819: [3, 4, 2, 1, 6, 7, 5, 0]
# Successful run 820: [7, 0, 5, 6, 2, 3, 1, 4]
# Successful run 821: [7, 3, 5, 1, 4, 0, 6, 2]
# Successful run 822: [6, 7, 3, 5, 2, 1, 4, 0]
# Successful run 823: [4, 3, 1, 2, 7, 5, 0, 6]
# Successful run 824: [1, 4, 0, 7, 2, 3, 6, 5]
# Successful run 825: [4, 0, 5, 2, 6, 3, 7, 1]
# Successful run 826: [6, 3, 1, 4, 5, 2, 7, 0]
# Successful run 827: [2, 0, 7, 5, 4, 6, 1, 3]
# Successful run 828: [2, 7, 1, 5, 6, 3, 0, 4]
# Successful run 829: [2, 0, 3, 6, 5, 7, 1, 4]
# Successful run 830: [6, 1, 5, 7, 4, 3, 0, 2]
# Successful run 831: [2, 4, 5, 0, 3, 7, 1, 6]
# Successful run 832: [0, 6, 1, 2, 7, 4, 5, 3]
# Successful run 833: [2, 1, 4, 3, 6, 0, 5, 7]
# Successful run 834: [7, 3, 5, 6, 2, 0, 4, 1]
# Successful run 835: [1, 0, 5, 7, 2, 3, 4, 6]
# Successful run 836: [4, 3, 1, 0, 5, 6, 2, 7]
# Successful run 837: [7, 3, 5, 6, 1, 4, 2, 0]
# Successful run 838: [3, 5, 4, 0, 6, 7, 1, 2]
# Successful run 839: [7, 4, 0, 1, 6, 5, 3, 2]
# Successful run 840: [3, 5, 4, 2, 0, 6, 7, 1]
# Successful run 841: [7, 4, 6, 3, 2, 0, 5, 1]
# Successful run 842: [5, 0, 3, 7, 2, 6, 4, 1]
# Successful run 843: [1, 0, 7, 6, 5, 4, 3, 2]
# Successful run 844: [2, 5, 1, 7, 0, 4, 3, 6]
# Successful run 845: [1, 6, 4, 5, 7, 2, 3, 0]
# Successful run 846: [4, 1, 0, 5, 3, 6, 2, 7]
# Successful run 847: [1, 3, 7, 4, 6, 5, 0, 2]
# Successful run 848: [6, 4, 5, 7, 2, 0, 1, 3]
# Successful run 849: [2, 4, 1, 7, 0, 5, 3, 6]
# Successful run 850: [3, 5, 7, 6, 0, 2, 4, 1]
# Successful run 851: [6, 2, 1, 7, 5, 3, 4, 0]
# Successful run 852: [7, 4, 6, 3, 5, 1, 2, 0]
# Successful run 853: [1, 5, 4, 0, 6, 2, 7, 3]
# Successful run 854: [0, 1, 5, 6, 2, 4, 3, 7]
# Successful run 855: [5, 3, 0, 4, 7, 2, 1, 6]
# Successful run 856: [4, 7, 0, 2, 6, 3, 5, 1]
# Successful run 857: [0, 7, 4, 6, 1, 3, 5, 2]
# Successful run 858: [2, 1, 6, 7, 4, 5, 0, 3]
# Successful run 859: [5, 3, 1, 2, 0, 6, 4, 7]
# Successful run 860: [7, 4, 0, 6, 3, 1, 2, 5]
# Successful run 861: [6, 1, 7, 4, 3, 2, 0, 5]
# Successful run 862: [3, 0, 1, 7, 4, 6, 5, 2]
# Successful run 863: [1, 6, 4, 7, 3, 5, 0, 2]
# Successful run 864: [6, 5, 3, 4, 0, 7, 2, 1]
# Successful run 865: [7, 5, 4, 0, 6, 3, 1, 2]
# Successful run 866: [5, 1, 7, 0, 3, 6, 2, 4]
# Successful run 867: [3, 0, 1, 6, 4, 5, 7, 2]
# Successful run 868: [0, 1, 5, 3, 7, 4, 2, 6]
# Successful run 869: [0, 7, 1, 3, 5, 6, 4, 2]
# Successful run 870: [7, 6, 0, 1, 2, 4, 3, 5]
# Successful run 871: [3, 5, 0, 7, 2, 6, 1, 4]
# Successful run 872: [3, 0, 7, 4, 2, 5, 1, 6]
# Successful run 873: [7, 0, 1, 4, 5, 2, 3, 6]
# Successful run 874: [4, 2, 3, 5, 6, 1, 0, 7]
# Successful run 875: [0, 6, 7, 4, 2, 1, 5, 3]
# Successful run 876: [1, 2, 7, 0, 3, 4, 5, 6]
# Successful run 877: [0, 4, 5, 1, 3, 6, 2, 7]
# Successful run 878: [3, 1, 7, 2, 0, 5, 4, 6]
# Successful run 879: [3, 5, 2, 7, 6, 1, 0, 4]
# Successful run 880: [4, 5, 1, 2, 0, 7, 6, 3]
# Successful run 881: [0, 3, 7, 2, 5, 1, 4, 6]
# Successful run 882: [6, 7, 4, 5, 1, 3, 0, 2]
# Successful run 883: [2, 3, 7, 0, 1, 5, 6, 4]
# Successful run 884: [6, 1, 5, 7, 2, 3, 4, 0]
# Successful run 885: [3, 2, 0, 6, 4, 1, 5, 7]
# Successful run 886: [1, 3, 2, 5, 7, 4, 6, 0]
# Successful run 887: [7, 5, 1, 6, 4, 0, 2, 3]
# Successful run 888: [6, 1, 4, 3, 7, 2, 0, 5]
# Successful run 889: [6, 0, 2, 3, 7, 5, 4, 1]
# Successful run 890: [5, 3, 7, 2, 1, 6, 4, 0]
# Successful run 891: [3, 1, 4, 5, 2, 6, 7, 0]
# Successful run 892: [0, 5, 4, 3, 2, 7, 6, 1]
# Successful run 893: [0, 2, 7, 1, 3, 4, 6, 5]
# Successful run 894: [0, 2, 5, 6, 7, 3, 1, 4]
# Successful run 895: [0, 7, 1, 5, 3, 6, 4, 2]
# Successful run 896: [7, 0, 4, 5, 3, 6, 1, 2]
# Successful run 897: [4, 6, 2, 0, 7, 1, 3, 5]
# Successful run 898: [4, 2, 5, 1, 7, 3, 6, 0]
# Successful run 899: [0, 4, 2, 7, 3, 6, 5, 1]
# Successful run 900: [3, 1, 5, 7, 4, 6, 2, 0]
# Successful run 901: [6, 3, 7, 1, 4, 5, 2, 0]
# Successful run 902: [0, 5, 4, 6, 3, 2, 7, 1]
# Successful run 903: [2, 4, 7, 5, 0, 1, 6, 3]
# Successful run 904: [2, 1, 5, 6, 3, 7, 0, 4]
# Successful run 905: [7, 3, 2, 4, 6, 5, 0, 1]
# Successful run 906: [5, 4, 2, 7, 1, 3, 6, 0]
# Successful run 907: [7, 5, 3, 0, 4, 1, 2, 6]
# Successful run 908: [5, 7, 0, 4, 6, 1, 3, 2]
# Successful run 909: [7, 2, 0, 3, 1, 5, 4, 6]
# Successful run 910: [4, 3, 5, 2, 0, 6, 7, 1]
# Successful run 911: [2, 4, 6, 7, 0, 3, 1, 5]
# Successful run 912: [3, 5, 2, 7, 4, 6, 0, 1]
# Successful run 913: [3, 0, 1, 7, 5, 6, 2, 4]
# Successful run 914: [5, 0, 6, 7, 2, 1, 3, 4]
# Successful run 915: [6, 1, 7, 3, 4, 2, 5, 0]
# Successful run 916: [6, 2, 4, 7, 1, 5, 3, 0]
# Successful run 917: [2, 5, 1, 0, 4, 3, 7, 6]
# Successful run 918: [7, 5, 4, 3, 6, 2, 1, 0]
# Successful run 919: [7, 2, 6, 3, 0, 1, 4, 5]
# Successful run 920: [5, 7, 2, 3, 4, 0, 6, 1]
# Successful run 921: [5, 7, 2, 3, 4, 0, 1, 6]
# Successful run 922: [5, 1, 3, 0, 7, 4, 6, 2]
# Successful run 923: [2, 1, 3, 4, 7, 6, 5, 0]
# Successful run 924: [4, 7, 0, 3, 5, 6, 2, 1]
# Successful run 925: [1, 3, 0, 6, 7, 2, 4, 5]
# Successful run 926: [6, 1, 7, 2, 0, 4, 5, 3]
# Successful run 927: [3, 5, 7, 1, 4, 6, 0, 2]
# Successful run 928: [2, 4, 5, 1, 6, 0, 3, 7]
# Successful run 929: [7, 5, 6, 4, 2, 0, 1, 3]
# Successful run 930: [0, 1, 4, 6, 3, 2, 7, 5]
# Successful run 931: [7, 0, 4, 6, 5, 2, 1, 3]
# Successful run 932: [4, 0, 3, 7, 6, 5, 2, 1]
# Successful run 933: [0, 3, 1, 4, 5, 6, 2, 7]
# Successful run 934: [5, 1, 6, 2, 7, 3, 4, 0]
# Successful run 935: [6, 7, 3, 5, 4, 2, 0, 1]
# Successful run 936: [0, 2, 7, 3, 1, 6, 4, 5]
# Successful run 937: [1, 6, 4, 2, 5, 0, 3, 7]
# Successful run 938: [1, 7, 5, 4, 0, 2, 3, 6]
# Successful run 939: [0, 7, 3, 5, 2, 1, 6, 4]
# Successful run 940: [3, 4, 7, 0, 5, 6, 1, 2]
# Successful run 941: [0, 7, 6, 4, 3, 2, 1, 5]
# Successful run 942: [1, 0, 2, 6, 7, 4, 3, 5]
# Successful run 943: [5, 6, 3, 4, 7, 1, 2, 0]
# Successful run 944: [7, 3, 5, 0, 6, 4, 2, 1]
# Successful run 945: [1, 4, 2, 5, 0, 3, 6, 7]
# Successful run 946: [6, 5, 1, 3, 0, 4, 7, 2]
# Successful run 947: [6, 0, 3, 7, 5, 1, 4, 2]
# Successful run 948: [1, 4, 5, 0, 6, 7, 2, 3]
# Successful run 949: [5, 0, 4, 6, 3, 1, 7, 2]
# Successful run 950: [5, 4, 3, 7, 0, 6, 2, 1]
# Successful run 951: [2, 7, 3, 5, 0, 6, 4, 1]
# Successful run 952: [0, 1, 3, 6, 7, 2, 5, 4]
# Successful run 953: [7, 4, 3, 1, 2, 5, 0, 6]
# Successful run 954: [0, 3, 7, 4, 5, 1, 6, 2]
# Successful run 955: [7, 1, 4, 6, 5, 2, 0, 3]
# Successful run 956: [2, 7, 3, 4, 5, 0, 6, 1]
# Successful run 957: [2, 5, 3, 6, 0, 4, 1, 7]
# Successful run 958: [7, 4, 1, 2, 6, 0, 3, 5]
# Successful run 959: [4, 0, 6, 3, 2, 7, 5, 1]
# Successful run 960: [2, 0, 7, 5, 1, 4, 3, 6]
# Successful run 961: [1, 6, 4, 7, 3, 0, 2, 5]
# Successful run 962: [0, 1, 4, 2, 3, 5, 6, 7]
# Successful run 963: [0, 4, 1, 6, 3, 7, 2, 5]
# Successful run 964: [2, 4, 3, 6, 5, 7, 0, 1]
# Successful run 965: [5, 0, 2, 1, 3, 6, 4, 7]
# Successful run 966: [3, 2, 5, 0, 7, 1, 6, 4]
# Successful run 967: [5, 3, 7, 6, 4, 0, 2, 1]
# Successful run 968: [5, 3, 4, 7, 6, 0, 2, 1]
# Successful run 969: [3, 6, 0, 5, 2, 7, 4, 1]
# Successful run 970: [0, 6, 7, 2, 4, 5, 3, 1]
# Successful run 971: [3, 1, 2, 6, 7, 4, 0, 5]
# Successful run 972: [2, 0, 1, 6, 5, 3, 4, 7]
# Successful run 973: [0, 1, 4, 5, 3, 6, 7, 2]
# Successful run 974: [7, 1, 6, 2, 5, 4, 0, 3]
# Successful run 975: [2, 3, 7, 1, 6, 4, 0, 5]
# Successful run 976: [7, 2, 6, 0, 4, 5, 1, 3]
# Successful run 977: [4, 6, 0, 2, 1, 3, 5, 7]
# Successful run 978: [3, 2, 4, 7, 1, 0, 5, 6]
# Successful run 979: [0, 3, 2, 5, 4, 7, 1, 6]
# Successful run 980: [0, 3, 6, 5, 7, 4, 1, 2]
# Successful run 981: [0, 3, 7, 6, 2, 4, 1, 5]
# Successful run 982: [5, 2, 0, 4, 7, 3, 1, 6]
# Successful run 983: [4, 2, 5, 1, 3, 7, 0, 6]
# Successful run 984: [6, 0, 1, 5, 4, 7, 2, 3]
# Successful run 985: [3, 4, 2, 5, 6, 7, 1, 0]
# Successful run 986: [2, 1, 5, 6, 3, 7, 0, 4]
# Successful run 987: [2, 5, 7, 1, 0, 6, 3, 4]
# Successful run 988: [3, 7, 0, 5, 4, 1, 6, 2]
# Successful run 989: [3, 2, 0, 1, 7, 5, 4, 6]
# Successful run 990: [1, 6, 2, 4, 7, 5, 3, 0]
# Successful run 991: [2, 5, 6, 1, 4, 0, 3, 7]
# Successful run 992: [5, 2, 4, 0, 6, 7, 3, 1]
# Successful run 993: [0, 4, 2, 7, 1, 5, 6, 3]
# Successful run 994: [0, 4, 1, 7, 5, 3, 2, 6]
# Successful run 995: [3, 1, 6, 2, 7, 5, 0, 4]
# Successful run 996: [1, 2, 3, 6, 7, 5, 0, 4]
# Successful run 997: [5, 3, 1, 4, 7, 6, 2, 0]
# Successful run 998: [4, 7, 6, 2, 5, 3, 0, 1]
# Successful run 999: [5, 6, 7, 3, 2, 1, 0, 4]
# Successful run 1000: [2, 0, 3, 1, 4, 5, 7, 6]
# Success rate: 1000 out of 1000
# No unsuccessful runs.
# Succeeded 1000 times out of 1000 runs.
# Failed 0 times out of 1000 runs.
